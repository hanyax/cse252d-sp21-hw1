# %% [markdown]
# # CSE252D Spring 2021: Homework 1
# ## Computing Resources
# Please read the README file of this repository for the instructions
# ## Instructions
# 1. Attempt all questions.
# 2. Please comment all your code adequately.
# 3. Include all relevant information such as text answers, output images in notebook.
# 4. **Academic integrity:** The homework must be completed individually.
#
# 5. **Submission instructions:**
#  (a) Submit the notebook and its PDF version on Gradescope.
#  (b) Rename your submission files as Lastname_Firstname.ipynb and Lastname_Firstname.pdf.
#  (c) Correctly select pages for each answer on Gradescope to allow proper grading.
#
# 6. **Due date:** Assignments are due Wed, May 5, by 4pm PST.

# %% [markdown]
# ## Question 1: Warm Up

# %% [markdown]
# We will first try SFM using the original implementation from $\mathtt{libviso2}$[8],[9]. We will test on a dataset containing 300 images from one sequence of the KITTI dataset with ground-truth camera poses and camera calibration information.
#
# Run the SFM algorithm using the following script. You are required to report two error metrics. The error metric for rotation is defined as the mean of Frobenius norm of the difference between the ground-truth rotation matrix and predicted rotation matrix. The error metric for translation is defined as mean of the L2 distance. Both errors will be printed on the screen as you run the code.  **(5 points)**

# %%
import os
import sys
# change your base path
os.chdir('./pyviso/') # './'
print(os.getcwd())

# %%
import os
import numpy as np
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)
import viso2
import matplotlib.pyplot as plt
from skimage.io import imread
import time

def errorMetric(RPred, RGt, TPred, TGt):
    diffRot = (RPred - RGt)
    diffTrans = (TPred - TGt)
    errorRot = np.sqrt(np.sum(np.multiply(diffRot.reshape(-1), diffRot.reshape(-1))))
    errorTrans = np.sqrt(np.sum(np.multiply(diffTrans.reshape(-1), diffTrans.reshape(-1))))

    return errorRot, errorTrans

if_vis = True # set to True to do the visualization per frame; the images will be saved at '.vis/'. Turn off if you just want the camera poses and errors
if_on_screen = False # if True the visualization per frame is going to be displayed realtime on screen; if False there will be no display, but in both options the images will be saved

# parameter settings (for an example, please download
# dataset_path = '../dataset'
dataset_path = '/datasets/cs252-sp21-A00-public/dataset_SfM' # On the ``ieng6.ucsd.edu`` server
img_dir      = os.path.join(dataset_path, 'sequences/00/image_0')
gt_dir       = os.path.join(dataset_path, 'poses/00.txt')
calibFile    = os.path.join(dataset_path, 'sequences/00/calib.txt')
border       = 50;
gap          = 15;

# Load the camera calibration information
with open(calibFile) as fid:
    calibLines = fid.readlines()
    calibLines = [calibLine.strip() for calibLine in calibLines]

calibInfo = [float(calibStr) for calibStr in calibLines[0].split(' ')[1:]]
# param = {'f': calibInfo[0], 'cu': calibInfo[2], 'cv': calibInfo[6]}

# Load the ground-truth depth and rotation
with open(gt_dir) as fid:
    gtTr = [[float(TrStr) for TrStr in line.strip().split(' ')] for line in fid.readlines()]
gtTr = np.asarray(gtTr).reshape(-1, 3, 4)

# param['height'] = 1.6
# param['pitch']  = -0.08
# param['match'] = {'pre_step_size': 64}
first_frame  = 0
last_frame   = 300
epi = 1e-8

# init visual odometry
params = viso2.Mono_parameters()
params.calib.f = calibInfo[0]
params.calib.cu = calibInfo[2]
params.calib.cv = calibInfo[6]
params.height = 1.6
params.pitch = -0.08


first_frame  = 0
last_frame   = 300

# init transformation matrix array
Tr_total = []
Tr_total_np = []
Tr_total.append(viso2.Matrix_eye(4))
Tr_total_np.append(np.eye(4))

# init viso module
visoMono = viso2.VisualOdometryMono(params)

if if_vis:
    save_path = 'vis'
    os.makedirs(save_path, exist_ok=True)

    # create figure
    fig = plt.figure(figsize=(10, 15))
    ax1 = plt.subplot(211)
    ax1.axis('off')
    ax2 = plt.subplot(212)
    ax2.set_xticks(np.arange(-100, 100, step=10))
    ax2.set_yticks(np.arange(-500, 500, step=10))
    ax2.axis('equal')
    ax2.grid()
    if if_on_screen:
        plt.ion()
    else:
        plt.ioff()

# %%
# for all frames do
if_replace = False
errorTransSum = 0
errorRotSum = 0
errorRot_list = []
errorTrans_list =[]

for frame in range(first_frame, last_frame):
    # 1-based index
    k = frame-first_frame+1

    # read current images
    I = imread(os.path.join(img_dir, '%06d.png'%frame))
    assert(len(I.shape) == 2) # should be grayscale

    # compute egomotion
    process_result = visoMono.process_frame(I, if_replace)
    Tr = visoMono.getMotion()
    matrixer = viso2.Matrix(Tr)
    Tr_np = np.zeros((4, 4))
    Tr.toNumpy(Tr_np) # so awkward...

    # accumulate egomotion, starting with second frame
    if k > 1:
        if process_result is False:
            if_replace = True
            Tr_total.append(Tr_total[-1])
            Tr_total_np.append(Tr_total_np[-1])
        else:
            if_replace = False
            Tr_total.append(Tr_total[-1] * viso2.Matrix_inv(Tr))
            Tr_total_np.append(Tr_total_np[-1] @ np.linalg.inv(Tr_np)) # should be the same
            print(Tr_total_np[-1])

    # output statistics
    num_matches = visoMono.getNumberOfMatches()
    num_inliers = visoMono.getNumberOfInliers()
    matches = visoMono.getMatches()
    matches_np = np.empty([4, matches.size()])

    for i,m in enumerate(matches):
        matches_np[:, i] = (m.u1p, m.v1p, m.u1c, m.v1c)

    if if_vis:
        # update image
        ax1.clear()
        ax1.imshow(I, cmap='gray', vmin=0, vmax=255)
        if num_matches != 0:
            for n in range(num_matches):
                ax1.plot([matches_np[0, n], matches_np[2, n]], [matches_np[1, n], matches_np[3, n]])
        ax1.set_title('Frame %d'%frame)

        # update trajectory
        if k > 1:
            ax2.plot([Tr_total_np[k-2][0, 3], Tr_total_np[k-1][0, 3]], \
                [Tr_total_np[k-2][2, 3], Tr_total_np[k-1][2, 3]], 'b.-', linewidth=1)
            ax2.plot([gtTr[k-2][0, 3], gtTr[k-1][0, 3]], \
                [gtTr[k-2][2, 3], gtTr[k-1][2, 3]], 'r.-', linewidth=1)
        ax2.set_title('Blue: estimated trajectory; Red: ground truth trejectory')

        plt.draw()

    # Compute rotation
    Rpred_p = Tr_total_np[k-2][0:3, 0:3]
    Rpred_c = Tr_total_np[k-1][0:3, 0:3]
    Rpred = Rpred_c.transpose() @ Rpred_p
    Rgt_p = np.squeeze(gtTr[k-2, 0:3, 0:3])
    Rgt_c = np.squeeze(gtTr[k-1, 0:3, 0:3])
    Rgt = Rgt_c.transpose() @ Rgt_p
    # Compute translation
    Tpred_p = Tr_total_np[k-2][0:3, 3:4]
    Tpred_c = Tr_total_np[k-1][0:3, 3:4]
    Tpred = Tpred_c - Tpred_p
    Tgt_p = gtTr[k-2, 0:3, 3:4]
    Tgt_c = gtTr[k-1, 0:3, 3:4]
    Tgt = Tgt_c - Tgt_p
    # Compute errors
    errorRot, errorTrans = errorMetric(Rpred, Rgt, Tpred, Tgt)
    errorRotSum = errorRotSum + errorRot
    errorTransSum = errorTransSum + errorTrans
    # errorRot_list.append(errorRot)
    # errorTrans_list.append(errorTrans)
    print('Mean Error Rotation: %.5f'%(errorRotSum / (k-1+epi)))
    print('Mean Error Translation: %.5f'%(errorTransSum / (k-1+epi)))



    print('== [Result] Frame: %d, Matches %d, Inliers: %.2f'%(frame, num_matches, 100*num_inliers/(num_matches+1e-8)))

    if if_vis:
        # input('Paused; Press Enter to continue') # Option 1: Manually pause and resume
        if if_on_screen:
            plt.pause(0.1) # Or Option 2: enable to this to auto pause for a while after daring to enable animation in case of a delay in drawing
        vis_path = os.path.join(save_path, 'frame%03d.jpg'%frame)
        fig.savefig(vis_path)
        print('Saved at %s'%vis_path)
        
        if frame % 50 == 0 or frame == last_frame-1:
            plt.figure(figsize=(10, 15))
            plt.imshow(plt.imread(vis_path))
            plt.axis('off')
            plt.show()


# input('Press Enter to exit')
# Out:
# Mean Error Rotation: 6947558.55240
# Mean Error Translation: 9718750861.05217
# == [Result] Frame: 0, Matches 0, Inliers: 0.00
# Saved at vis/frame000.jpg
# [[ 1.     -0.0027 -0.0031 -0.0032]
#  [ 0.0027  1.     -0.0026  0.0011]
#  [ 0.0031  0.0026  1.      0.4828]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.07468
# Mean Error Translation: 97.56708
# == [Result] Frame: 1, Matches 320, Inliers: 86.87
# Saved at vis/frame001.jpg
# [[ 1.     -0.0022 -0.0078 -0.0051]
#  [ 0.0022  1.     -0.0041 -0.0018]
#  [ 0.0078  0.0041  1.      0.9579]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.03918
# Mean Error Translation: 48.97651
# == [Result] Frame: 2, Matches 325, Inliers: 81.23
# Saved at vis/frame002.jpg
# [[ 0.9999 -0.0057 -0.014   0.0024]
#  [ 0.0056  1.     -0.0053 -0.0075]
#  [ 0.014   0.0052  0.9999  1.4471]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.02883
# Mean Error Translation: 32.77574
# == [Result] Frame: 3, Matches 329, Inliers: 82.67
# Saved at vis/frame003.jpg
# [[ 0.9998 -0.0058 -0.0197 -0.0071]
#  [ 0.0057  1.     -0.006  -0.0118]
#  [ 0.0197  0.0059  0.9998  1.9428]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.02293
# Mean Error Translation: 24.67299
# == [Result] Frame: 4, Matches 338, Inliers: 77.51
# Saved at vis/frame004.jpg
# [[ 0.9997 -0.0048 -0.0237 -0.0264]
#  [ 0.0047  1.     -0.006  -0.0198]
#  [ 0.0237  0.0058  0.9997  2.4355]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.01901
# Mean Error Translation: 19.81189
# == [Result] Frame: 5, Matches 316, Inliers: 83.23
# Saved at vis/frame005.jpg
# [[ 0.9996 -0.0044 -0.029  -0.0366]
#  [ 0.0042  1.     -0.0068 -0.0312]
#  [ 0.0291  0.0066  0.9996  2.9298]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.01662
# Mean Error Translation: 16.57085
# == [Result] Frame: 6, Matches 318, Inliers: 82.70
# Saved at vis/frame006.jpg
# [[ 0.9994 -0.0031 -0.0343 -0.0547]
#  [ 0.0028  1.     -0.0077 -0.0347]
#  [ 0.0343  0.0076  0.9994  3.4464]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.01492
# Mean Error Translation: 14.25277
# == [Result] Frame: 7, Matches 322, Inliers: 80.43
# Saved at vis/frame007.jpg
# [[ 0.9993 -0.0032 -0.0383 -0.0809]
#  [ 0.0029  1.     -0.0059 -0.0429]
#  [ 0.0383  0.0058  0.9992  3.9632]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.01369
# Mean Error Translation: 12.51394
# == [Result] Frame: 8, Matches 324, Inliers: 82.72
# Saved at vis/frame008.jpg
# [[ 0.9991 -0.0035 -0.0429 -0.1048]
#  [ 0.0033  1.     -0.0036 -0.0469]
#  [ 0.0429  0.0034  0.9991  4.5226]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.01287
# Mean Error Translation: 11.15695
# == [Result] Frame: 9, Matches 334, Inliers: 82.04
# Saved at vis/frame009.jpg
# [[ 0.9989 -0.0029 -0.0462 -0.1343]
#  [ 0.0029  1.     -0.0009 -0.054 ]
#  [ 0.0462  0.0008  0.9989  5.078 ]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.01215
# Mean Error Translation: 10.07173
# == [Result] Frame: 10, Matches 318, Inliers: 84.59
# Saved at vis/frame010.jpg
# [[ 0.9988 -0.0014 -0.0488 -0.1695]
#  [ 0.0014  1.     -0.0016 -0.0605]
#  [ 0.0488  0.0016  0.9988  5.643 ]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.01120
# Mean Error Translation: 9.18278
# == [Result] Frame: 11, Matches 328, Inliers: 85.37
# Saved at vis/frame011.jpg
# [[ 0.9988 -0.0008 -0.0498 -0.2134]
#  [ 0.0007  1.     -0.0021 -0.0641]
#  [ 0.0498  0.0021  0.9988  6.2313]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.01042
# Mean Error Translation: 8.44019
# == [Result] Frame: 12, Matches 321, Inliers: 86.60
# Saved at vis/frame012.jpg
# [[ 0.9986 -0.0055 -0.0526 -0.2361]
#  [ 0.0053  1.     -0.0029 -0.0678]
#  [ 0.0526  0.0026  0.9986  6.8204]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.01019
# Mean Error Translation: 7.81184
# == [Result] Frame: 13, Matches 325, Inliers: 85.23
# Saved at vis/frame013.jpg
# [[ 0.9985 -0.0055 -0.0545 -0.2698]
#  [ 0.0054  1.     -0.0019 -0.0747]
#  [ 0.0545  0.0016  0.9985  7.4062]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00969
# Mean Error Translation: 7.27336
# == [Result] Frame: 14, Matches 320, Inliers: 75.62
# Saved at vis/frame014.jpg
# [[ 0.9984 -0.0069 -0.0562 -0.3031]
#  [ 0.0068  1.     -0.0024 -0.0801]
#  [ 0.0562  0.002   0.9984  8.0042]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00911
# Mean Error Translation: 6.80564
# == [Result] Frame: 15, Matches 315, Inliers: 82.86
# Saved at vis/frame015.jpg
# [[ 0.9983 -0.0059 -0.0585 -0.3386]
#  [ 0.0056  1.     -0.0054 -0.083 ]
#  [ 0.0585  0.0051  0.9983  8.6102]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00865
# Mean Error Translation: 6.39638
# == [Result] Frame: 16, Matches 293, Inliers: 82.94
# Saved at vis/frame016.jpg
# [[ 0.9982 -0.0062 -0.0602 -0.3764]
#  [ 0.0057  0.9999 -0.0087 -0.0853]
#  [ 0.0603  0.0084  0.9981  9.2362]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00825
# Mean Error Translation: 6.03451
# == [Result] Frame: 17, Matches 307, Inliers: 83.39
# Saved at vis/frame017.jpg
# [[ 0.9981 -0.0022 -0.062  -0.4226]
#  [ 0.0016  0.9999 -0.0105 -0.0941]
#  [ 0.0621  0.0104  0.998   9.8581]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00782
# Mean Error Translation: 5.71363
# == [Result] Frame: 18, Matches 301, Inliers: 85.05
# Saved at vis/frame018.jpg
# [[ 0.998  -0.0025 -0.0632 -0.467 ]
#  [ 0.0019  0.9999 -0.0105 -0.1033]
#  [ 0.0632  0.0103  0.9979 10.5134]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00752
# Mean Error Translation: 5.42531
# == [Result] Frame: 19, Matches 316, Inliers: 82.91
# Saved at vis/frame019.jpg
# [[ 0.9979 -0.0047 -0.0647 -0.5122]
#  [ 0.0041  1.     -0.0091 -0.1163]
#  [ 0.0647  0.0088  0.9979 11.1852]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00728
# Mean Error Translation: 5.16548
# == [Result] Frame: 20, Matches 310, Inliers: 85.48
# Saved at vis/frame020.jpg
# [[ 0.9978 -0.0034 -0.0656 -0.566 ]
#  [ 0.0029  1.     -0.008  -0.125 ]
#  [ 0.0656  0.0078  0.9978 11.8662]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00702
# Mean Error Translation: 4.93019
# == [Result] Frame: 21, Matches 317, Inliers: 79.81
# Saved at vis/frame021.jpg
# [[ 0.9978 -0.0041 -0.0663 -0.6143]
#  [ 0.0036  1.     -0.0079 -0.1376]
#  [ 0.0664  0.0077  0.9978 12.5174]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00674
# Mean Error Translation: 4.71792
# == [Result] Frame: 22, Matches 323, Inliers: 80.50
# Saved at vis/frame022.jpg
# [[ 0.9977 -0.0032 -0.0671 -0.6739]
#  [ 0.0026  1.     -0.0091 -0.1473]
#  [ 0.0671  0.0089  0.9977 13.18  ]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00653
# Mean Error Translation: 4.52373
# == [Result] Frame: 23, Matches 313, Inliers: 78.27
# Saved at vis/frame023.jpg
# [[ 0.9977 -0.006  -0.0679 -0.7217]
#  [ 0.0054  0.9999 -0.0099 -0.1576]
#  [ 0.068   0.0095  0.9976 13.82  ]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00633
# Mean Error Translation: 4.34680
# == [Result] Frame: 24, Matches 302, Inliers: 84.11
# Saved at vis/frame024.jpg
# [[ 0.9976 -0.0063 -0.0688 -0.7642]
#  [ 0.0057  0.9999 -0.0084 -0.1682]
#  [ 0.0689  0.0079  0.9976 14.4808]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00608
# Mean Error Translation: 4.18359
# == [Result] Frame: 25, Matches 300, Inliers: 77.33
# Saved at vis/frame025.jpg
# [[ 0.9976 -0.0063 -0.069  -0.8113]
#  [ 0.006   1.     -0.005  -0.1784]
#  [ 0.069   0.0046  0.9976 15.1495]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00595
# Mean Error Translation: 4.03293
# == [Result] Frame: 26, Matches 285, Inliers: 75.09
# Saved at vis/frame026.jpg
# [[ 0.9977 -0.004  -0.0679 -0.8658]
#  [ 0.0039  1.     -0.0017 -0.1863]
#  [ 0.0679  0.0014  0.9977 15.8347]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00581
# Mean Error Translation: 3.89286
# == [Result] Frame: 27, Matches 290, Inliers: 77.59
# Saved at vis/frame027.jpg
# [[ 0.9978 -0.0042 -0.0662 -0.9122]
#  [ 0.0043  1.      0.0009 -0.1923]
#  [ 0.0662 -0.0012  0.9978 16.504 ]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00564
# Mean Error Translation: 3.76361
# == [Result] Frame: 28, Matches 283, Inliers: 81.27
# Saved at vis/frame028.jpg
# [[ 0.9979 -0.0026 -0.0645 -0.9674]
#  [ 0.0027  1.      0.0014 -0.197 ]
#  [ 0.0645 -0.0015  0.9979 17.2502]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00555
# Mean Error Translation: 3.64073
# == [Result] Frame: 29, Matches 302, Inliers: 76.16
# Saved at vis/frame029.jpg
# [[ 0.998  -0.0025 -0.0634 -1.0124]
#  [ 0.0024  1.     -0.0015 -0.2053]
#  [ 0.0634  0.0013  0.998  17.942 ]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00538
# Mean Error Translation: 3.52792
# == [Result] Frame: 30, Matches 300, Inliers: 84.67
# Saved at vis/frame030.jpg
# [[ 0.998  -0.0017 -0.0633 -1.0514]
#  [ 0.0013  1.     -0.0061 -0.2162]
#  [ 0.0634  0.006   0.998  18.6366]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00526
# Mean Error Translation: 3.42243
# == [Result] Frame: 31, Matches 290, Inliers: 79.31
# Saved at vis/frame031.jpg
# [[ 0.9981 -0.0005 -0.0611 -1.1033]
#  [-0.      1.     -0.009  -0.2258]
#  [ 0.0612  0.009   0.9981 19.2957]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00519
# Mean Error Translation: 3.32485
# == [Result] Frame: 32, Matches 303, Inliers: 82.18
# Saved at vis/frame032.jpg
# [[ 0.9981 -0.0043 -0.0621 -1.1303]
#  [ 0.0039  1.     -0.0077 -0.2411]
#  [ 0.0621  0.0074  0.998  19.9495]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00513
# Mean Error Translation: 3.23366
# == [Result] Frame: 33, Matches 280, Inliers: 76.43
# Saved at vis/frame033.jpg
# [[ 0.9981 -0.0046 -0.0622 -1.175 ]
#  [ 0.0045  1.     -0.0026 -0.2516]
#  [ 0.0622  0.0023  0.9981 20.6084]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00503
# Mean Error Translation: 3.14788
# == [Result] Frame: 34, Matches 282, Inliers: 75.18
# Saved at vis/frame034.jpg
# [[ 0.998  -0.0077 -0.0633 -1.22  ]
#  [ 0.0078  1.      0.0007 -0.2615]
#  [ 0.0633 -0.0011  0.998  21.3241]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00492
# Mean Error Translation: 3.06549
# == [Result] Frame: 35, Matches 277, Inliers: 75.81
# Saved at vis/frame035.jpg
# [[ 0.9977 -0.0166 -0.0652 -1.2517]
#  [ 0.0166  0.9999  0.0003 -0.272 ]
#  [ 0.0652 -0.0014  0.9979 22.0132]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00484
# Mean Error Translation: 2.98841
# == [Result] Frame: 36, Matches 276, Inliers: 75.72
# Saved at vis/frame036.jpg
# [[ 0.9976 -0.0194 -0.067  -1.2884]
#  [ 0.0192  0.9998 -0.0036 -0.2803]
#  [ 0.067   0.0023  0.9977 22.6424]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00473
# Mean Error Translation: 2.91712
# == [Result] Frame: 37, Matches 257, Inliers: 76.26
# Saved at vis/frame037.jpg
# [[ 0.9974 -0.0203 -0.0689 -1.3331]
#  [ 0.0198  0.9998 -0.0076 -0.2896]
#  [ 0.069   0.0062  0.9976 23.314 ]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00467
# Mean Error Translation: 2.84859
# == [Result] Frame: 38, Matches 280, Inliers: 77.14
# Saved at vis/frame038.jpg
# [[ 0.9972 -0.0193 -0.0719 -1.3722]
#  [ 0.0188  0.9998 -0.0082 -0.302 ]
#  [ 0.0721  0.0068  0.9974 23.9231]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00460
# Mean Error Translation: 2.78589
# == [Result] Frame: 39, Matches 281, Inliers: 80.43
# Saved at vis/frame039.jpg
# [[ 0.9971 -0.0191 -0.0735 -1.4148]
#  [ 0.0186  0.9998 -0.0065 -0.3155]
#  [ 0.0736  0.0051  0.9973 24.5432]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00451
# Mean Error Translation: 2.72724
# == [Result] Frame: 40, Matches 283, Inliers: 75.97
# Saved at vis/frame040.jpg
# [[ 0.9971 -0.0154 -0.0744 -1.4711]
#  [ 0.0151  0.9999 -0.0042 -0.3238]
#  [ 0.0745  0.0031  0.9972 25.1835]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00443
# Mean Error Translation: 2.67057
# == [Result] Frame: 41, Matches 276, Inliers: 76.45
# Saved at vis/frame041.jpg
# [[ 0.997  -0.015  -0.0759 -1.5216]
#  [ 0.0148  0.9999 -0.003  -0.3336]
#  [ 0.0759  0.0018  0.9971 25.8221]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00434
# Mean Error Translation: 2.61668
# == [Result] Frame: 42, Matches 279, Inliers: 73.12
# Saved at vis/frame042.jpg
# [[ 0.9968 -0.0167 -0.0775 -1.5617]
#  [ 0.0167  0.9999 -0.0006 -0.3405]
#  [ 0.0775 -0.0007  0.997  26.4454]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00433
# Mean Error Translation: 2.56539
# == [Result] Frame: 43, Matches 267, Inliers: 74.53
# Saved at vis/frame043.jpg
# [[ 0.9968 -0.0185 -0.0777 -1.611 ]
#  [ 0.0186  0.9998  0.0016 -0.3435]
#  [ 0.0777 -0.0031  0.997  27.0872]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00430
# Mean Error Translation: 2.51607
# == [Result] Frame: 44, Matches 266, Inliers: 74.44
# Saved at vis/frame044.jpg
# [[ 0.9968 -0.0127 -0.0787 -1.6704]
#  [ 0.013   0.9999  0.0037 -0.3502]
#  [ 0.0786 -0.0047  0.9969 27.7475]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00422
# Mean Error Translation: 2.46824
# == [Result] Frame: 45, Matches 263, Inliers: 78.71
# Saved at vis/frame045.jpg
# [[ 0.9968 -0.0128 -0.0791 -1.7282]
#  [ 0.0131  0.9999  0.0032 -0.3586]
#  [ 0.079  -0.0042  0.9969 28.4473]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00416
# Mean Error Translation: 2.42161
# == [Result] Frame: 46, Matches 271, Inliers: 81.92
# Saved at vis/frame046.jpg
# [[ 0.9968 -0.0121 -0.0785 -1.794 ]
#  [ 0.0122  0.9999  0.0012 -0.3623]
#  [ 0.0785 -0.0022  0.9969 29.1674]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00411
# Mean Error Translation: 2.37628
# == [Result] Frame: 47, Matches 278, Inliers: 80.22
# Saved at vis/frame047.jpg
# [[ 0.9969 -0.0082 -0.0784 -1.8586]
#  [ 0.0081  1.     -0.0013 -0.3698]
#  [ 0.0784  0.0006  0.9969 29.8567]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00408
# Mean Error Translation: 2.33337
# == [Result] Frame: 48, Matches 286, Inliers: 81.12
# Saved at vis/frame048.jpg
# [[ 0.9968 -0.0096 -0.0793 -1.919 ]
#  [ 0.0096  1.     -0.0012 -0.3803]
#  [ 0.0793  0.0004  0.9968 30.5637]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00403
# Mean Error Translation: 2.29177
# == [Result] Frame: 49, Matches 282, Inliers: 83.33
# Saved at vis/frame049.jpg
# [[ 0.9967 -0.0108 -0.0804 -1.977 ]
#  [ 0.0108  0.9999 -0.     -0.3923]
#  [ 0.0804 -0.0008  0.9968 31.262 ]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00398
# Mean Error Translation: 2.25197
# == [Result] Frame: 50, Matches 276, Inliers: 80.07
# Saved at vis/frame050.jpg
# [[ 0.9967 -0.0098 -0.0811 -2.0378]
#  [ 0.0099  1.      0.0011 -0.4046]
#  [ 0.0811 -0.0019  0.9967 31.9888]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00392
# Mean Error Translation: 2.21309
# == [Result] Frame: 51, Matches 283, Inliers: 75.62
# Saved at vis/frame051.jpg
# [[ 0.9966 -0.0084 -0.082  -2.1024]
#  [ 0.0081  1.     -0.0029 -0.4128]
#  [ 0.082   0.0023  0.9966 32.7704]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00391
# Mean Error Translation: 2.17449
# == [Result] Frame: 52, Matches 300, Inliers: 80.33
# Saved at vis/frame052.jpg
# [[ 0.9965 -0.0091 -0.0829 -2.1695]
#  [ 0.0085  0.9999 -0.0072 -0.4254]
#  [ 0.083   0.0065  0.9965 33.5207]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00388
# Mean Error Translation: 2.13777
# == [Result] Frame: 53, Matches 307, Inliers: 79.48
# Saved at vis/frame053.jpg
# [[ 0.9964 -0.0095 -0.0846 -2.2358]
#  [ 0.0088  0.9999 -0.0085 -0.4417]
#  [ 0.0847  0.0077  0.9964 34.4381]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00384
# Mean Error Translation: 2.09941
# == [Result] Frame: 54, Matches 309, Inliers: 85.44
# Saved at vis/frame054.jpg
# [[ 0.9963 -0.0117 -0.085  -2.3048]
#  [ 0.0113  0.9999 -0.005  -0.4571]
#  [ 0.085   0.004   0.9964 35.2252]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00383
# Mean Error Translation: 2.06478
# == [Result] Frame: 55, Matches 299, Inliers: 78.60
# Saved at vis/frame055.jpg
# [[ 0.9963 -0.0136 -0.0854 -2.3708]
#  [ 0.0135  0.9999 -0.0017 -0.4725]
#  [ 0.0854  0.0005  0.9963 35.9699]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00378
# Mean Error Translation: 2.03206
# == [Result] Frame: 56, Matches 305, Inliers: 80.00
# Saved at vis/frame056.jpg
# [[ 0.9961 -0.0156 -0.0864 -2.4278]
#  [ 0.0156  0.9999 -0.0008 -0.4857]
#  [ 0.0864 -0.0005  0.9963 36.6944]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00374
# Mean Error Translation: 2.00073
# == [Result] Frame: 57, Matches 309, Inliers: 80.26
# Saved at vis/frame057.jpg
# [[ 0.996  -0.0185 -0.0871 -2.4808]
#  [ 0.0183  0.9998 -0.0024 -0.4948]
#  [ 0.0871  0.0008  0.9962 37.3812]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00370
# Mean Error Translation: 1.97101
# == [Result] Frame: 58, Matches 308, Inliers: 74.68
# Saved at vis/frame058.jpg
# [[ 0.9959 -0.0218 -0.0875 -2.5379]
#  [ 0.0215  0.9998 -0.0045 -0.501 ]
#  [ 0.0876  0.0026  0.9962 38.0483]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00364
# Mean Error Translation: 1.94265
# == [Result] Frame: 59, Matches 313, Inliers: 78.59
# Saved at vis/frame059.jpg
# [[ 0.9958 -0.0251 -0.0884 -2.5978]
#  [ 0.0249  0.9997 -0.0039 -0.5074]
#  [ 0.0885  0.0017  0.9961 38.7185]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00363
# Mean Error Translation: 1.91509
# == [Result] Frame: 60, Matches 291, Inliers: 75.95
# Saved at vis/frame060.jpg
# [[ 0.9956 -0.0276 -0.0893 -2.6636]
#  [ 0.0278  0.9996  0.     -0.5173]
#  [ 0.0893 -0.0025  0.996  39.4044]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00358
# Mean Error Translation: 1.88823
# == [Result] Frame: 61, Matches 315, Inliers: 77.14
# Saved at vis/frame061.jpg
# [[ 0.9955 -0.0281 -0.0905 -2.7228]
#  [ 0.0286  0.9996  0.005  -0.5281]
#  [ 0.0903 -0.0075  0.9959 40.0953]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00355
# Mean Error Translation: 1.86214
# == [Result] Frame: 62, Matches 314, Inliers: 78.03
# Saved at vis/frame062.jpg
# [[ 0.9954 -0.0276 -0.0918 -2.7837]
#  [ 0.0284  0.9996  0.0072 -0.5367]
#  [ 0.0916 -0.0098  0.9957 40.799 ]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00353
# Mean Error Translation: 1.83652
# == [Result] Frame: 63, Matches 309, Inliers: 82.52
# Saved at vis/frame063.jpg
# [[ 0.9951 -0.0282 -0.095  -2.8373]
#  [ 0.0286  0.9996  0.0025 -0.5403]
#  [ 0.0949 -0.0052  0.9955 41.5069]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00355
# Mean Error Translation: 1.81149
# == [Result] Frame: 64, Matches 290, Inliers: 82.07
# Saved at vis/frame064.jpg
# [[ 0.995  -0.027  -0.0965 -2.9064]
#  [ 0.0266  0.9996 -0.0057 -0.5478]
#  [ 0.0966  0.0031  0.9953 42.1993]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00350
# Mean Error Translation: 1.78720
# == [Result] Frame: 65, Matches 293, Inliers: 81.57
# Saved at vis/frame065.jpg
# [[ 0.9949 -0.0259 -0.0978 -2.9719]
#  [ 0.025   0.9996 -0.0111 -0.5592]
#  [ 0.098   0.0086  0.9951 42.8733]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00346
# Mean Error Translation: 1.76379
# == [Result] Frame: 66, Matches 294, Inliers: 80.61
# Saved at vis/frame066.jpg
# [[ 0.9949 -0.0211 -0.0987 -3.0457]
#  [ 0.0202  0.9997 -0.0103 -0.5749]
#  [ 0.0989  0.0082  0.9951 43.5263]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00342
# Mean Error Translation: 1.74131
# == [Result] Frame: 67, Matches 295, Inliers: 80.34
# Saved at vis/frame067.jpg
# [[ 0.9948 -0.0178 -0.1    -3.1204]
#  [ 0.0171  0.9998 -0.0081 -0.5924]
#  [ 0.1001  0.0064  0.995  44.2142]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00339
# Mean Error Translation: 1.71881
# == [Result] Frame: 68, Matches 306, Inliers: 81.70
# Saved at vis/frame068.jpg
# [[ 0.9949 -0.0128 -0.1001 -3.2052]
#  [ 0.0122  0.9999 -0.0066 -0.6103]
#  [ 0.1001  0.0054  0.995  44.8654]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00339
# Mean Error Translation: 1.69727
# == [Result] Frame: 69, Matches 297, Inliers: 83.16
# Saved at vis/frame069.jpg
# [[ 0.9947 -0.0124 -0.1016 -3.2725]
#  [ 0.0117  0.9999 -0.0072 -0.6218]
#  [ 0.1017  0.006   0.9948 45.5155]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00335
# Mean Error Translation: 1.67616
# == [Result] Frame: 70, Matches 295, Inliers: 81.69
# Saved at vis/frame070.jpg
# [[ 0.9947 -0.0088 -0.1027 -3.3537]
#  [ 0.0082  0.9999 -0.0066 -0.6346]
#  [ 0.1027  0.0057  0.9947 46.1659]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00335
# Mean Error Translation: 1.65544
# == [Result] Frame: 71, Matches 283, Inliers: 79.15
# Saved at vis/frame071.jpg
# [[ 0.9943 -0.0102 -0.1057 -3.4096]
#  [ 0.0096  0.9999 -0.0059 -0.6526]
#  [ 0.1058  0.0048  0.9944 46.8083]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00337
# Mean Error Translation: 1.63524
# == [Result] Frame: 72, Matches 294, Inliers: 80.27
# Saved at vis/frame072.jpg
# [[ 0.994  -0.0107 -0.109  -3.4609]
#  [ 0.0102  0.9999 -0.0052 -0.6745]
#  [ 0.109   0.0041  0.994  47.45  ]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00335
# Mean Error Translation: 1.61541
# == [Result] Frame: 73, Matches 272, Inliers: 80.15
# Saved at vis/frame073.jpg
# [[ 0.9937 -0.0136 -0.1117 -3.5182]
#  [ 0.0132  0.9999 -0.0042 -0.6877]
#  [ 0.1117  0.0027  0.9937 48.1149]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00336
# Mean Error Translation: 1.59564
# == [Result] Frame: 74, Matches 283, Inliers: 84.10
# Saved at vis/frame074.jpg
# [[ 0.9933 -0.0123 -0.1145 -3.5822]
#  [ 0.0122  0.9999 -0.0016 -0.7024]
#  [ 0.1145  0.0002  0.9934 48.7542]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00335
# Mean Error Translation: 1.57657
# == [Result] Frame: 75, Matches 289, Inliers: 76.82
# Saved at vis/frame075.jpg
# [[ 0.993  -0.0117 -0.1172 -3.6558]
#  [ 0.012   0.9999  0.0025 -0.7147]
#  [ 0.1171 -0.0039  0.9931 49.4549]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00335
# Mean Error Translation: 1.55706
# == [Result] Frame: 76, Matches 288, Inliers: 82.64
# Saved at vis/frame076.jpg
# [[ 0.9928 -0.0106 -0.1197 -3.7388]
#  [ 0.0112  0.9999  0.0043 -0.7278]
#  [ 0.1196 -0.0056  0.9928 50.1719]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00334
# Mean Error Translation: 1.53767
# == [Result] Frame: 77, Matches 295, Inliers: 85.76
# Saved at vis/frame077.jpg
# [[ 0.9926 -0.0089 -0.1214 -3.8183]
#  [ 0.009   1.      0.0002 -0.7413]
#  [ 0.1214 -0.0013  0.9926 50.8094]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00332
# Mean Error Translation: 1.51945
# == [Result] Frame: 78, Matches 294, Inliers: 85.71
# Saved at vis/frame078.jpg
# [[ 0.9924 -0.0098 -0.123  -3.8939]
#  [ 0.0089  0.9999 -0.0072 -0.754 ]
#  [ 0.123   0.006   0.9924 51.4028]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00330
# Mean Error Translation: 1.50197
# == [Result] Frame: 79, Matches 305, Inliers: 82.95
# Saved at vis/frame079.jpg
# [[ 0.9922 -0.0108 -0.124  -3.9653]
#  [ 0.0092  0.9999 -0.0134 -0.7638]
#  [ 0.1241  0.0121  0.9922 51.9368]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00327
# Mean Error Translation: 1.48544
# == [Result] Frame: 80, Matches 315, Inliers: 86.03
# Saved at vis/frame080.jpg
# [[ 0.9922 -0.0092 -0.1246 -4.0301]
#  [ 0.0075  0.9999 -0.0143 -0.7764]
#  [ 0.1247  0.0133  0.9921 52.4438]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00325
# Mean Error Translation: 1.46942
# == [Result] Frame: 81, Matches 327, Inliers: 82.26
# Saved at vis/frame081.jpg
# [[ 0.9918 -0.0097 -0.1276 -4.077 ]
#  [ 0.0083  0.9999 -0.011  -0.7906]
#  [ 0.1277  0.0098  0.9918 52.9236]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00328
# Mean Error Translation: 1.45391
# == [Result] Frame: 82, Matches 320, Inliers: 84.37
# Saved at vis/frame082.jpg
# [[ 0.9916 -0.0102 -0.1287 -4.1429]
#  [ 0.0092  0.9999 -0.0086 -0.8084]
#  [ 0.1288  0.0074  0.9916 53.3925]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00328
# Mean Error Translation: 1.43866
# == [Result] Frame: 83, Matches 321, Inliers: 85.67
# Saved at vis/frame083.jpg
# [[ 0.9912 -0.0157 -0.1315 -4.1794]
#  [ 0.0143  0.9998 -0.0118 -0.8263]
#  [ 0.1317  0.0098  0.9912 53.8186]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00328
# Mean Error Translation: 1.42399
# == [Result] Frame: 84, Matches 325, Inliers: 89.54
# Saved at vis/frame084.jpg
# [[ 0.991  -0.0242 -0.1314 -4.2272]
#  [ 0.0222  0.9996 -0.0168 -0.8406]
#  [ 0.1317  0.0138  0.9912 54.2157]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00325
# Mean Error Translation: 1.40977
# == [Result] Frame: 85, Matches 324, Inliers: 88.89
# Saved at vis/frame085.jpg
# [[ 0.9906 -0.0331 -0.1331 -4.2492]
#  [ 0.0304  0.9993 -0.0224 -0.8486]
#  [ 0.1337  0.0181  0.9909 54.6032]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00330
# Mean Error Translation: 1.39581
# == [Result] Frame: 86, Matches 323, Inliers: 89.78
# Saved at vis/frame086.jpg
# [[ 0.9913 -0.0286 -0.1284 -4.3147]
#  [ 0.0259  0.9994 -0.023  -0.8586]
#  [ 0.129   0.0194  0.9915 54.9694]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00331
# Mean Error Translation: 1.38225
# == [Result] Frame: 87, Matches 319, Inliers: 88.71
# Saved at vis/frame087.jpg
# [[ 0.992  -0.0234 -0.1241 -4.3685]
#  [ 0.0211  0.9996 -0.02   -0.8697]
#  [ 0.1246  0.0172  0.9921 55.3314]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00329
# Mean Error Translation: 1.36891
# == [Result] Frame: 88, Matches 318, Inliers: 90.57
# Saved at vis/frame088.jpg
# [[ 0.9922 -0.0275 -0.1212 -4.3939]
#  [ 0.0257  0.9995 -0.0166 -0.886 ]
#  [ 0.1216  0.0133  0.9925 55.6941]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00331
# Mean Error Translation: 1.35570
# == [Result] Frame: 89, Matches 325, Inliers: 91.08
# Saved at vis/frame089.jpg
# [[ 0.9929 -0.0306 -0.1152 -4.4389]
#  [ 0.0293  0.9995 -0.0132 -0.8885]
#  [ 0.1155  0.0097  0.9933 56.0629]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00330
# Mean Error Translation: 1.34260
# == [Result] Frame: 90, Matches 327, Inliers: 85.93
# Saved at vis/frame090.jpg
# [[ 0.9936 -0.0356 -0.1075 -4.4688]
#  [ 0.0348  0.9993 -0.0095 -0.9014]
#  [ 0.1078  0.0057  0.9942 56.4311]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00328
# Mean Error Translation: 1.32964
# == [Result] Frame: 91, Matches 325, Inliers: 89.23
# Saved at vis/frame091.jpg
# [[ 0.9947 -0.0335 -0.0972 -4.4995]
#  [ 0.0327  0.9994 -0.0095 -0.9091]
#  [ 0.0974  0.0062  0.9952 56.7869]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00326
# Mean Error Translation: 1.31689
# == [Result] Frame: 92, Matches 325, Inliers: 88.00
# Saved at vis/frame092.jpg
# [[ 0.9963 -0.0279 -0.0814 -4.5375]
#  [ 0.0272  0.9996 -0.0098 -0.9146]
#  [ 0.0816  0.0075  0.9966 57.1355]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00324
# Mean Error Translation: 1.30438
# == [Result] Frame: 93, Matches 341, Inliers: 90.03
# Saved at vis/frame093.jpg
# [[ 0.9976 -0.0249 -0.0643 -4.5473]
#  [ 0.0244  0.9997 -0.0086 -0.9235]
#  [ 0.0645  0.007   0.9979 57.4843]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00324
# Mean Error Translation: 1.29198
# == [Result] Frame: 94, Matches 347, Inliers: 88.18
# Saved at vis/frame094.jpg
# [[ 0.9987 -0.0285 -0.0433 -4.5436]
#  [ 0.0282  0.9996 -0.0073 -0.9302]
#  [ 0.0435  0.0061  0.999  57.8366]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00324
# Mean Error Translation: 1.27967
# == [Result] Frame: 95, Matches 337, Inliers: 87.24
# Saved at vis/frame095.jpg
# [[ 0.9993 -0.0323 -0.0166 -4.5406]
#  [ 0.0322  0.9995 -0.0058 -0.9321]
#  [ 0.0168  0.0053  0.9998 58.1764]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00322
# Mean Error Translation: 1.26763
# == [Result] Frame: 96, Matches 346, Inliers: 89.02
# Saved at vis/frame096.jpg
# [[ 0.9993 -0.0352  0.0119 -4.5154]
#  [ 0.0352  0.9994 -0.0032 -0.9385]
#  [-0.0117  0.0037  0.9999 58.5102]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00321
# Mean Error Translation: 1.25581
# == [Result] Frame: 97, Matches 338, Inliers: 87.87
# Saved at vis/frame097.jpg
# [[ 0.9983 -0.0388  0.0426 -4.4674]
#  [ 0.0389  0.9992 -0.0012 -0.94  ]
#  [-0.0426  0.0029  0.9991 58.8394]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00324
# Mean Error Translation: 1.24420
# == [Result] Frame: 98, Matches 333, Inliers: 87.09
# Saved at vis/frame098.jpg
# [[ 0.996  -0.0387  0.0807 -4.4269]
#  [ 0.0387  0.9992  0.001  -0.9439]
#  [-0.0806  0.0021  0.9967 59.1777]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00323
# Mean Error Translation: 1.23264
# == [Result] Frame: 99, Matches 332, Inliers: 87.95
# Saved at vis/frame099.jpg
# [[ 0.9917 -0.0391  0.1222 -4.3659]
#  [ 0.0391  0.9992  0.0029 -0.9481]
#  [-0.1223  0.0019  0.9925 59.5015]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00321
# Mean Error Translation: 1.22141
# == [Result] Frame: 100, Matches 332, Inliers: 84.04
# Saved at vis/frame100.jpg
# [[ 0.9851 -0.0388  0.1675 -4.2895]
#  [ 0.0385  0.9992  0.0049 -0.9483]
#  [-0.1676  0.0017  0.9859 59.8246]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00319
# Mean Error Translation: 1.21033
# == [Result] Frame: 101, Matches 330, Inliers: 83.64
# Saved at vis/frame101.jpg
# [[ 0.9759 -0.0385  0.2149 -4.183 ]
#  [ 0.0383  0.9993  0.0048 -0.9526]
#  [-0.2149  0.0035  0.9766 60.1273]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00319
# Mean Error Translation: 1.19938
# == [Result] Frame: 102, Matches 336, Inliers: 87.20
# Saved at vis/frame102.jpg
# [[ 0.9631 -0.0423  0.2659 -4.0492]
#  [ 0.0427  0.9991  0.0045 -0.9628]
#  [-0.2658  0.007   0.964  60.4066]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00322
# Mean Error Translation: 1.18879
# == [Result] Frame: 103, Matches 342, Inliers: 85.67
# Saved at vis/frame103.jpg
# [[ 0.9461 -0.0455  0.3206 -3.9106]
#  [ 0.0461  0.9989  0.0057 -0.969 ]
#  [-0.3205  0.0094  0.9472 60.6805]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00323
# Mean Error Translation: 1.17822
# == [Result] Frame: 104, Matches 338, Inliers: 86.98
# Saved at vis/frame104.jpg
# [[ 0.9245 -0.0446  0.3785 -3.7691]
#  [ 0.0453  0.9989  0.0071 -0.9652]
#  [-0.3784  0.0106  0.9256 60.9488]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00322
# Mean Error Translation: 1.16798
# == [Result] Frame: 105, Matches 339, Inliers: 89.09
# Saved at vis/frame105.jpg
# [[ 0.8991 -0.0475  0.4352 -3.5921]
#  [ 0.0489  0.9988  0.0079 -0.9601]
#  [-0.435   0.0142  0.9003 61.1965]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00324
# Mean Error Translation: 1.15784
# == [Result] Frame: 106, Matches 329, Inliers: 83.59
# Saved at vis/frame106.jpg
# [[ 0.8702 -0.0522  0.49   -3.3911]
#  [ 0.0554  0.9984  0.0079 -0.9525]
#  [-0.4897  0.0203  0.8717 61.4114]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00327
# Mean Error Translation: 1.14784
# == [Result] Frame: 107, Matches 329, Inliers: 84.80
# Saved at vis/frame107.jpg
# [[ 0.8386 -0.0547  0.5421 -3.1717]
#  [ 0.0595  0.9982  0.0086 -0.9417]
#  [-0.5415  0.025   0.8403 61.6145]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00331
# Mean Error Translation: 1.13810
# == [Result] Frame: 108, Matches 336, Inliers: 82.14
# Saved at vis/frame108.jpg
# [[ 0.8035 -0.0574  0.5925 -2.9463]
#  [ 0.0625  0.998   0.0119 -0.9281]
#  [-0.5919  0.0275  0.8055 61.8164]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00334
# Mean Error Translation: 1.12836
# == [Result] Frame: 109, Matches 340, Inliers: 81.47
# Saved at vis/frame109.jpg
# [[ 0.7675 -0.0604  0.6382 -2.7046]
#  [ 0.0658  0.9977  0.0154 -0.9144]
#  [-0.6376  0.0302  0.7697 61.9774]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00341
# Mean Error Translation: 1.11907
# == [Result] Frame: 110, Matches 337, Inliers: 81.90
# Saved at vis/frame110.jpg
# [[ 0.7256 -0.0614  0.6853 -2.468 ]
#  [ 0.0659  0.9976  0.0196 -0.9049]
#  [-0.6849  0.0309  0.728  62.1714]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00339
# Mean Error Translation: 1.10973
# == [Result] Frame: 111, Matches 330, Inliers: 82.42
# Saved at vis/frame111.jpg
# [[ 0.6845 -0.0645  0.7261 -2.212 ]
#  [ 0.071   0.9972  0.0217 -0.898 ]
#  [-0.7255  0.0367  0.6872 62.3139]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00342
# Mean Error Translation: 1.10058
# == [Result] Frame: 112, Matches 337, Inliers: 84.27
# Saved at vis/frame112.jpg
# [[ 0.6417 -0.0685  0.7639 -1.9396]
#  [ 0.0784  0.9966  0.0236 -0.8814]
#  [-0.7629  0.0447  0.645  62.4607]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00343
# Mean Error Translation: 1.09151
# == [Result] Frame: 113, Matches 329, Inliers: 82.07
# Saved at vis/frame113.jpg
# [[ 0.599  -0.0669  0.798  -1.6814]
#  [ 0.0759  0.9968  0.0266 -0.8754]
#  [-0.7971  0.0446  0.6021 62.6005]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00341
# Mean Error Translation: 1.08266
# == [Result] Frame: 114, Matches 335, Inliers: 87.76
# Saved at vis/frame114.jpg
# [[ 0.5549 -0.0645  0.8294 -1.417 ]
#  [ 0.0713  0.997   0.0299 -0.8713]
#  [-0.8288  0.0426  0.5579 62.7404]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00340
# Mean Error Translation: 1.07398
# == [Result] Frame: 115, Matches 331, Inliers: 87.92
# Saved at vis/frame115.jpg
# [[ 0.5125 -0.0624  0.8564 -1.1531]
#  [ 0.0692  0.9971  0.0313 -0.8626]
#  [-0.8559  0.0432  0.5154 62.8586]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00338
# Mean Error Translation: 1.06554
# == [Result] Frame: 116, Matches 338, Inliers: 85.21
# Saved at vis/frame116.jpg
# [[ 0.4728 -0.0656  0.8787 -0.8678]
#  [ 0.075   0.9966  0.0341 -0.8523]
#  [-0.878   0.0497  0.4761 62.9587]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00337
# Mean Error Translation: 1.05710
# == [Result] Frame: 117, Matches 332, Inliers: 85.54
# Saved at vis/frame117.jpg
# [[ 0.4352 -0.0744  0.8972 -0.4225]
#  [ 0.09    0.9952  0.0389 -0.826 ]
#  [-0.8958  0.0638  0.4398 63.0805]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00336
# Mean Error Translation: 1.04882
# == [Result] Frame: 118, Matches 331, Inliers: 85.50
# Saved at vis/frame118.jpg
# [[ 0.4009 -0.0787  0.9127  0.1802]
#  [ 0.0924  0.9947  0.0452 -0.8071]
#  [-0.9114  0.0662  0.4061 63.2835]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00336
# Mean Error Translation: 1.04215
# == [Result] Frame: 119, Matches 327, Inliers: 80.12
# Saved at vis/frame119.jpg
# [[ 0.3693 -0.0749  0.9263  0.8219]
#  [ 0.0891  0.995   0.0449 -0.7823]
#  [-0.925   0.0659  0.3742 63.4952]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00333
# Mean Error Translation: 1.03592
# == [Result] Frame: 120, Matches 327, Inliers: 81.04
# Saved at vis/frame120.jpg
# [[ 0.3397 -0.0664  0.9382  1.404 ]
#  [ 0.0754  0.9962  0.0432 -0.776 ]
#  [-0.9375  0.0561  0.3434 63.7137]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00332
# Mean Error Translation: 1.02934
# == [Result] Frame: 121, Matches 325, Inliers: 82.46
# Saved at vis/frame121.jpg
# [[ 0.3116 -0.0609  0.9483  2.0358]
#  [ 0.0681  0.9968  0.0417 -0.7575]
#  [-0.9478  0.0516  0.3147 63.9265]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00331
# Mean Error Translation: 1.02321
# == [Result] Frame: 122, Matches 338, Inliers: 79.59
# Saved at vis/frame122.jpg
# [[ 0.2878 -0.0598  0.9558  2.7757]
#  [ 0.0694  0.9967  0.0414 -0.7413]
#  [-0.9552  0.0544  0.291  64.0763]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00330
# Mean Error Translation: 1.01776
# == [Result] Frame: 123, Matches 330, Inliers: 80.30
# Saved at vis/frame123.jpg
# [[ 0.2642 -0.0589  0.9627  3.4618]
#  [ 0.0754  0.9963  0.0403 -0.7133]
#  [-0.9615  0.062   0.2677 64.2274]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00329
# Mean Error Translation: 1.01196
# == [Result] Frame: 124, Matches 335, Inliers: 80.60
# Saved at vis/frame124.jpg
# [[ 0.2437 -0.053   0.9684  4.238 ]
#  [ 0.0814  0.9961  0.034  -0.6616]
#  [-0.9664  0.0705  0.247  64.3854]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00328
# Mean Error Translation: 1.00687
# == [Result] Frame: 125, Matches 346, Inliers: 77.46
# Saved at vis/frame125.jpg
# [[ 0.2244 -0.0462  0.9734  5.1216]
#  [ 0.0823  0.9962  0.0283 -0.6046]
#  [-0.971   0.0738  0.2274 64.5568]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00327
# Mean Error Translation: 1.00266
# == [Result] Frame: 126, Matches 328, Inliers: 76.83
# Saved at vis/frame126.jpg
# [[ 0.2084 -0.045   0.977   6.2446]
#  [ 0.0783  0.9965  0.0292 -0.5675]
#  [-0.9749  0.0704  0.2112 64.7594]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00326
# Mean Error Translation: 1.00023
# == [Result] Frame: 127, Matches 332, Inliers: 77.11
# Saved at vis/frame127.jpg
# [[ 0.1934 -0.0491  0.9799  7.1728]
#  [ 0.0771  0.9964  0.0347 -0.5502]
#  [-0.9781  0.0688  0.1965 64.9261]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00326
# Mean Error Translation: 0.99616
# == [Result] Frame: 128, Matches 317, Inliers: 78.86
# Saved at vis/frame128.jpg
# [[ 0.179  -0.0522  0.9825  7.4958]
#  [ 0.076   0.9963  0.0391 -0.5426]
#  [-0.9809  0.0677  0.1823 64.9809]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00324
# Mean Error Translation: 0.98964
# == [Result] Frame: 129, Matches 320, Inliers: 78.12
# Saved at vis/frame129.jpg
# [[ 0.1655 -0.0536  0.9848  8.1869]
#  [ 0.0761  0.9962  0.0415 -0.5073]
#  [-0.9833  0.0681  0.1689 65.092 ]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00324
# Mean Error Translation: 0.98378
# == [Result] Frame: 130, Matches 315, Inliers: 72.70
# Saved at vis/frame130.jpg
# [[ 0.1538 -0.0546  0.9866  8.5394]
#  [ 0.0793  0.9959  0.0427 -0.4923]
#  [-0.9849  0.0717  0.1576 65.1382]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00322
# Mean Error Translation: 0.97742
# == [Result] Frame: 131, Matches 320, Inliers: 77.19
# Saved at vis/frame131.jpg
# [[ 0.1438 -0.0538  0.9881  8.9158]
#  [ 0.0819  0.9957  0.0422 -0.4747]
#  [-0.9862  0.0749  0.1476 65.1855]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00320
# Mean Error Translation: 0.97112
# == [Result] Frame: 132, Matches 327, Inliers: 81.65
# Saved at vis/frame132.jpg
# [[ 0.1359 -0.0532  0.9893  9.3034]
#  [ 0.0829  0.9957  0.0422 -0.4597]
#  [-0.9872  0.0763  0.1398 65.2358]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00319
# Mean Error Translation: 0.96494
# == [Result] Frame: 133, Matches 321, Inliers: 83.49
# Saved at vis/frame133.jpg
# [[ 0.13   -0.0526  0.9901  9.6952]
#  [ 0.0837  0.9956  0.0419 -0.4443]
#  [-0.988   0.0774  0.1338 65.2898]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00317
# Mean Error Translation: 0.95895
# == [Result] Frame: 134, Matches 321, Inliers: 83.80
# Saved at vis/frame134.jpg
# [[ 0.1241 -0.0519  0.9909 10.1025]
#  [ 0.0839  0.9956  0.0416 -0.4315]
#  [-0.9887  0.0779  0.1279 65.3436]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00316
# Mean Error Translation: 0.95306
# == [Result] Frame: 135, Matches 312, Inliers: 81.09
# Saved at vis/frame135.jpg
# [[ 0.119  -0.0511  0.9916 10.5186]
#  [ 0.0846  0.9956  0.0411 -0.4149]
#  [-0.9893  0.079   0.1228 65.3877]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00315
# Mean Error Translation: 0.94732
# == [Result] Frame: 136, Matches 306, Inliers: 82.03
# Saved at vis/frame136.jpg
# [[ 0.114  -0.0509  0.9922 10.9458]
#  [ 0.0841  0.9956  0.0414 -0.4011]
#  [-0.9899  0.0787  0.1178 65.4445]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00315
# Mean Error Translation: 0.94174
# == [Result] Frame: 137, Matches 304, Inliers: 75.99
# Saved at vis/frame137.jpg
# [[ 0.1109 -0.0509  0.9925 11.393 ]
#  [ 0.0852  0.9955  0.0415 -0.3829]
#  [-0.9902  0.0799  0.1148 65.4957]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00314
# Mean Error Translation: 0.93623
# == [Result] Frame: 138, Matches 308, Inliers: 74.68
# Saved at vis/frame138.jpg
# [[ 0.1076 -0.0515  0.9929 11.865 ]
#  [ 0.0864  0.9954  0.0423 -0.3659]
#  [-0.9904  0.0812  0.1115 65.5495]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00312
# Mean Error Translation: 0.93077
# == [Result] Frame: 139, Matches 320, Inliers: 79.37
# Saved at vis/frame139.jpg
# [[ 0.105  -0.0521  0.9931 12.3497]
#  [ 0.0881  0.9952  0.0429 -0.3465]
#  [-0.9906  0.083   0.1091 65.6011]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00311
# Mean Error Translation: 0.92541
# == [Result] Frame: 140, Matches 316, Inliers: 78.16
# Saved at vis/frame140.jpg
# [[ 0.1044 -0.0528  0.9931 12.857 ]
#  [ 0.0926  0.9948  0.0431 -0.3281]
#  [-0.9902  0.0874  0.1088 65.6501]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00309
# Mean Error Translation: 0.92010
# == [Result] Frame: 141, Matches 293, Inliers: 76.79
# Saved at vis/frame141.jpg
# [[ 0.1048 -0.0533  0.9931 13.3505]
#  [ 0.0951  0.9945  0.0433 -0.3104]
#  [-0.9899  0.0899  0.1093 65.7073]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00309
# Mean Error Translation: 0.91506
# == [Result] Frame: 142, Matches 307, Inliers: 76.22
# Saved at vis/frame142.jpg
# [[ 0.1075 -0.0534  0.9928 13.9072]
#  [ 0.0969  0.9944  0.043  -0.2881]
#  [-0.9895  0.0916  0.1121 65.7658]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00308
# Mean Error Translation: 0.90981
# == [Result] Frame: 143, Matches 315, Inliers: 76.51
# Saved at vis/frame143.jpg
# [[ 0.1106 -0.0537  0.9924 14.4537]
#  [ 0.0997  0.9941  0.0427 -0.2693]
#  [-0.9888  0.0942  0.1153 65.8361]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00306
# Mean Error Translation: 0.90481
# == [Result] Frame: 144, Matches 311, Inliers: 78.46
# Saved at vis/frame144.jpg
# [[ 0.1139 -0.054   0.992  14.9875]
#  [ 0.0997  0.9941  0.0427 -0.2503]
#  [-0.9885  0.0941  0.1186 65.913 ]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00305
# Mean Error Translation: 0.90008
# == [Result] Frame: 145, Matches 308, Inliers: 86.36
# Saved at vis/frame145.jpg
# [[ 0.1167 -0.0555  0.9916 15.5353]
#  [ 0.0989  0.9941  0.044  -0.2311]
#  [-0.9882  0.093   0.1215 65.9936]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00305
# Mean Error Translation: 0.89544
# == [Result] Frame: 146, Matches 313, Inliers: 82.43
# Saved at vis/frame146.jpg
# [[ 0.121  -0.0572  0.991  16.097 ]
#  [ 0.1007  0.9939  0.045  -0.2079]
#  [-0.9875  0.0943  0.126  66.0624]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00305
# Mean Error Translation: 0.89084
# == [Result] Frame: 147, Matches 309, Inliers: 82.85
# Saved at vis/frame147.jpg
# [[ 0.126  -0.0591  0.9903 16.6794]
#  [ 0.0989  0.994   0.0467 -0.1852]
#  [-0.9871  0.0921  0.1311 66.1365]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00304
# Mean Error Translation: 0.88626
# == [Result] Frame: 148, Matches 298, Inliers: 80.54
# Saved at vis/frame148.jpg
# [[ 0.13   -0.0604  0.9897 17.2726]
#  [ 0.098   0.994   0.0478 -0.1651]
#  [-0.9867  0.0908  0.1352 66.225 ]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00302
# Mean Error Translation: 0.88173
# == [Result] Frame: 149, Matches 299, Inliers: 83.95
# Saved at vis/frame149.jpg
# [[ 0.1353 -0.0597  0.989  17.8744]
#  [ 0.0969  0.9942  0.0467 -0.144 ]
#  [-0.9861  0.0895  0.1403 66.3063]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00302
# Mean Error Translation: 0.87724
# == [Result] Frame: 150, Matches 296, Inliers: 82.09
# Saved at vis/frame150.jpg
# [[ 0.1394 -0.0555  0.9887 18.4878]
#  [ 0.096   0.9945  0.0422 -0.1231]
#  [-0.9856  0.0891  0.1439 66.3944]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00301
# Mean Error Translation: 0.87276
# == [Result] Frame: 151, Matches 264, Inliers: 77.65
# Saved at vis/frame151.jpg
# [[ 0.1417 -0.0498  0.9887 19.0716]
#  [ 0.0906  0.9952  0.0371 -0.1028]
#  [-0.9858  0.0843  0.1455 66.485 ]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00300
# Mean Error Translation: 0.86855
# == [Result] Frame: 152, Matches 271, Inliers: 77.86
# Saved at vis/frame152.jpg
# [[ 0.1431 -0.0473  0.9886 19.6474]
#  [ 0.09    0.9953  0.0346 -0.09  ]
#  [-0.9856  0.084   0.1467 66.5619]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00301
# Mean Error Translation: 0.86446
# == [Result] Frame: 153, Matches 280, Inliers: 81.07
# Saved at vis/frame153.jpg
# [[ 0.1432 -0.0469  0.9886 20.2879]
#  [ 0.0869  0.9956  0.0346 -0.0687]
#  [-0.9859  0.081   0.1467 66.6656]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00299
# Mean Error Translation: 0.86011
# == [Result] Frame: 154, Matches 301, Inliers: 78.41
# Saved at vis/frame154.jpg
# [[ 0.1431 -0.0483  0.9885 20.8842]
#  [ 0.0818  0.996   0.0368 -0.0616]
#  [-0.9863  0.0756  0.1465 66.7716]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00300
# Mean Error Translation: 0.85607
# == [Result] Frame: 155, Matches 308, Inliers: 75.32
# Saved at vis/frame155.jpg
# [[ 0.1433 -0.0499  0.9884 21.5024]
#  [ 0.0854  0.9956  0.0379 -0.0458]
#  [-0.986   0.0789  0.1469 66.8605]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00300
# Mean Error Translation: 0.85194
# == [Result] Frame: 156, Matches 318, Inliers: 85.53
# Saved at vis/frame156.jpg
# [[ 0.1449 -0.0503  0.9882 22.1657]
#  [ 0.0842  0.9957  0.0383 -0.0262]
#  [-0.9859  0.0777  0.1485 66.9537]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00300
# Mean Error Translation: 0.84760
# == [Result] Frame: 157, Matches 311, Inliers: 81.35
# Saved at vis/frame157.jpg
# [[ 0.1446 -0.0498  0.9882 22.7825]
#  [ 0.0826  0.9959  0.0381 -0.0131]
#  [-0.986   0.0761  0.1481 67.0561]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00298
# Mean Error Translation: 0.84360
# == [Result] Frame: 158, Matches 318, Inliers: 82.70
# Saved at vis/frame158.jpg
# [[ 0.1455 -0.0494  0.9881 23.4462]
#  [ 0.0802  0.9961  0.0379 -0.0002]
#  [-0.9861  0.0737  0.1489 67.1588]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00297
# Mean Error Translation: 0.83934
# == [Result] Frame: 159, Matches 313, Inliers: 82.11
# Saved at vis/frame159.jpg
# [[ 0.1453 -0.0484  0.9882 24.0824]
#  [ 0.078   0.9963  0.0373  0.0114]
#  [-0.9863  0.0717  0.1486 67.2514]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00297
# Mean Error Translation: 0.83526
# == [Result] Frame: 160, Matches 297, Inliers: 86.20
# Saved at vis/frame160.jpg
# [[ 0.144  -0.0488  0.9884 24.7077]
#  [ 0.0759  0.9964  0.0381  0.026 ]
#  [-0.9867  0.0695  0.1471 67.3359]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00296
# Mean Error Translation: 0.83130
# == [Result] Frame: 161, Matches 311, Inliers: 80.71
# Saved at vis/frame161.jpg
# [[ 0.1411 -0.0498  0.9887 25.3581]
#  [ 0.0745  0.9964  0.0395  0.0447]
#  [-0.9872  0.0681  0.1443 67.4286]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00296
# Mean Error Translation: 0.82726
# == [Result] Frame: 162, Matches 327, Inliers: 79.20
# Saved at vis/frame162.jpg
# [[ 0.1369 -0.0516  0.9892 26.3798]
#  [ 0.0732  0.9964  0.0418  0.0801]
#  [-0.9879  0.0667  0.1402 67.5724]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00296
# Mean Error Translation: 0.82370
# == [Result] Frame: 163, Matches 322, Inliers: 79.19
# Saved at vis/frame163.jpg
# [[ 0.1305 -0.0528  0.99   27.0091]
#  [ 0.0702  0.9966  0.0439  0.1006]
#  [-0.989   0.0638  0.1338 67.6632]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00295
# Mean Error Translation: 0.81990
# == [Result] Frame: 164, Matches 317, Inliers: 73.19
# Saved at vis/frame164.jpg
# [[ 0.1225 -0.0522  0.9911 27.65  ]
#  [ 0.0671  0.9968  0.0442  0.1156]
#  [-0.9902  0.0611  0.1256 67.7558]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00295
# Mean Error Translation: 0.81607
# == [Result] Frame: 165, Matches 322, Inliers: 74.53
# Saved at vis/frame165.jpg
# [[ 0.1151 -0.0515  0.992  28.3059]
#  [ 0.0683  0.9967  0.0438  0.1369]
#  [-0.991   0.0627  0.1182 67.8186]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00295
# Mean Error Translation: 0.81214
# == [Result] Frame: 166, Matches 321, Inliers: 75.70
# Saved at vis/frame166.jpg
# [[ 0.1022 -0.0503  0.9935 28.948 ]
#  [ 0.0616  0.9971  0.0441  0.1501]
#  [-0.9929  0.0567  0.105  67.9244]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00300
# Mean Error Translation: 0.80845
# == [Result] Frame: 167, Matches 312, Inliers: 69.23
# Saved at vis/frame167.jpg
# [[ 0.0936 -0.0511  0.9943 29.9976]
#  [ 0.064   0.9969  0.0452  0.1894]
#  [-0.9936  0.0594  0.0966 67.9925]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00300
# Mean Error Translation: 0.80527
# == [Result] Frame: 168, Matches 317, Inliers: 76.66
# Saved at vis/frame168.jpg
# [[ 0.0809 -0.0526  0.9953 30.8604]
#  [ 0.059   0.9971  0.0479  0.2009]
#  [-0.995   0.0549  0.0838 68.0992]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00301
# Mean Error Translation: 0.80136
# == [Result] Frame: 169, Matches 316, Inliers: 72.78
# Saved at vis/frame169.jpg
# [[ 0.0698 -0.0534  0.9961 31.9733]
#  [ 0.0592  0.997   0.0493  0.2371]
#  [-0.9958  0.0555  0.0727 68.179 ]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00300
# Mean Error Translation: 0.79867
# == [Result] Frame: 170, Matches 315, Inliers: 76.83
# Saved at vis/frame170.jpg
# [[ 0.0589 -0.0527  0.9969 33.1178]
#  [ 0.0581  0.9971  0.0493  0.2813]
#  [-0.9966  0.055   0.0618 68.2457]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00299
# Mean Error Translation: 0.79622
# == [Result] Frame: 171, Matches 299, Inliers: 75.25
# Saved at vis/frame171.jpg
# [[ 0.049  -0.0526  0.9974 34.3206]
# ...
#  [ 0.0089  0.9988 -0.0482  0.3105]
#  [-0.1915  0.049   0.9803 84.8923]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00284
# Mean Error Translation: 0.62739
# == [Result] Frame: 237, Matches 290, Inliers: 72.41
# Saved at vis/frame237.jpg
# [[ 0.9818  0.0007  0.1898 55.8785]
#  [ 0.0078  0.999  -0.0439  0.2686]
#  [-0.1897  0.0446  0.9808 85.7779]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00284
# Mean Error Translation: 0.62559
# == [Result] Frame: 238, Matches 266, Inliers: 73.31
# Saved at vis/frame238.jpg
# [[ 0.9822 -0.0044  0.1877 55.9968]
#  [ 0.0116  0.9992 -0.037   0.2459]
#  [-0.1874  0.0386  0.9815 86.3603]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00284
# Mean Error Translation: 0.62355
# == [Result] Frame: 239, Matches 279, Inliers: 75.63
# Saved at vis/frame239.jpg
# [[ 0.9827 -0.0032  0.1852 56.097 ]
#  [ 0.0092  0.9995 -0.0315  0.2174]
#  [-0.185   0.0327  0.9822 86.9312]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00283
# Mean Error Translation: 0.62164
# == [Result] Frame: 240, Matches 282, Inliers: 79.43
# Saved at vis/frame240.jpg
# [[ 0.983   0.0014  0.1836 56.2523]
#  [ 0.0047  0.9995 -0.0326  0.1788]
#  [-0.1835  0.0329  0.9825 87.857 ]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00283
# Mean Error Translation: 0.61991
# == [Result] Frame: 241, Matches 277, Inliers: 72.56
# Saved at vis/frame241.jpg
# [[ 0.9833  0.007   0.1817 56.4081]
#  [-0.0001  0.9993 -0.0376  0.1393]
#  [-0.1818  0.0369  0.9826 88.8311]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00282
# Mean Error Translation: 0.61836
# == [Result] Frame: 242, Matches 271, Inliers: 76.01
# Saved at vis/frame242.jpg
# [[ 0.9839  0.0078  0.1787 56.5746]
#  [-0.0001  0.9991 -0.0431  0.0931]
#  [-0.1788  0.0424  0.983  89.8632]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00281
# Mean Error Translation: 0.61703
# == [Result] Frame: 243, Matches 278, Inliers: 74.10
# Saved at vis/frame243.jpg
# [[ 0.9842  0.0092  0.1767 56.658 ]
#  [-0.001   0.9989 -0.0467  0.0636]
#  [-0.177   0.0457  0.9832 90.4967]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00282
# Mean Error Translation: 0.61512
# == [Result] Frame: 244, Matches 272, Inliers: 75.00
# Saved at vis/frame244.jpg
# [[ 0.9848  0.0076  0.1736 56.7842]
#  [ 0.0003  0.999  -0.0454  0.0222]
#  [-0.1738  0.0447  0.9838 91.318 ]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00281
# Mean Error Translation: 0.61293
# == [Result] Frame: 245, Matches 253, Inliers: 76.28
# Saved at vis/frame245.jpg
# [[ 0.9855  0.0044  0.1699 56.9525]
#  [ 0.003   0.999  -0.0436 -0.0279]
#  [-0.1699  0.0434  0.9845 92.2701]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00281
# Mean Error Translation: 0.61116
# == [Result] Frame: 246, Matches 255, Inliers: 81.96
# Saved at vis/frame246.jpg
# [[ 0.9857  0.0044  0.1686 57.096 ]
#  [ 0.0025  0.9992 -0.0409 -0.0792]
#  [-0.1686  0.0408  0.9848 93.2078]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00281
# Mean Error Translation: 0.60930
# == [Result] Frame: 247, Matches 265, Inliers: 78.11
# Saved at vis/frame247.jpg
# [[ 0.9857  0.0018  0.1683 57.2102]
#  [ 0.0048  0.9992 -0.0387 -0.1156]
#  [-0.1682  0.039   0.985  93.9306]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00280
# Mean Error Translation: 0.60730
# == [Result] Frame: 248, Matches 279, Inliers: 78.49
# Saved at vis/frame248.jpg
# [[ 0.9858 -0.0034  0.168  57.3105]
#  [ 0.0099  0.9992 -0.0377 -0.1424]
#  [-0.1677  0.0388  0.9851 94.5062]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00279
# Mean Error Translation: 0.60586
# == [Result] Frame: 249, Matches 256, Inliers: 74.22
# Saved at vis/frame249.jpg
# [[ 0.986  -0.0031  0.1667 57.4151]
#  [ 0.0092  0.9993 -0.0358 -0.1717]
#  [-0.1664  0.0369  0.9854 95.0947]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00279
# Mean Error Translation: 0.60441
# == [Result] Frame: 250, Matches 248, Inliers: 73.79
# Saved at vis/frame250.jpg
# [[ 0.986   0.0012  0.1668 57.5067]
#  [ 0.0052  0.9993 -0.0378 -0.1999]
#  [-0.1667  0.0381  0.9853 95.6541]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00278
# Mean Error Translation: 0.60310
# == [Result] Frame: 251, Matches 255, Inliers: 72.16
# Saved at vis/frame251.jpg
# [[ 0.9856  0.0083  0.1689 57.5806]
#  [-0.0013  0.9991 -0.0414 -0.2268]
#  [-0.169   0.0406  0.9848 96.2237]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00278
# Mean Error Translation: 0.60179
# == [Result] Frame: 252, Matches 276, Inliers: 77.54
# Saved at vis/frame252.jpg
# [[ 0.9855  0.0156  0.1688 57.6784]
#  [-0.0084  0.999  -0.0432 -0.2537]
#  [-0.1693  0.0412  0.9847 96.8012]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00277
# Mean Error Translation: 0.60046
# == [Result] Frame: 253, Matches 274, Inliers: 78.83
# Saved at vis/frame253.jpg
# [[ 0.9853  0.0181  0.17   57.7884]
#  [-0.0109  0.999  -0.043  -0.2819]
#  [-0.1706  0.0405  0.9845 97.3917]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00279
# Mean Error Translation: 0.59910
# == [Result] Frame: 254, Matches 276, Inliers: 78.99
# Saved at vis/frame254.jpg
# [[ 0.9846  0.0211  0.1734 57.8798]
#  [-0.0142  0.9991 -0.0407 -0.3165]
#  [-0.1741  0.0376  0.984  97.9921]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00278
# Mean Error Translation: 0.59777
# == [Result] Frame: 255, Matches 256, Inliers: 77.73
# Saved at vis/frame255.jpg
# [[ 0.9842  0.021   0.176  57.9869]
#  [-0.0139  0.999  -0.0415 -0.349 ]
#  [-0.1767  0.0384  0.9835 98.6026]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00278
# Mean Error Translation: 0.59639
# == [Result] Frame: 256, Matches 264, Inliers: 85.23
# Saved at vis/frame256.jpg
# [[ 0.9838  0.0203  0.1784 58.0884]
#  [-0.0126  0.9989 -0.0443 -0.3812]
#  [-0.1791  0.0413  0.983  99.2129]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00277
# Mean Error Translation: 0.59504
# == [Result] Frame: 257, Matches 278, Inliers: 81.29
# Saved at vis/frame257.jpg
# [[ 0.9837  0.014   0.1793 58.2076]
#  [-0.0063  0.999  -0.0432 -0.4105]
#  [-0.1798  0.0414  0.9828 99.832 ]
#  [ 0.      0.      0.      1.    ]]
# Mean Error Rotation: 0.00276
# Mean Error Translation: 0.59371
# == [Result] Frame: 258, Matches 268, Inliers: 83.58
# Saved at vis/frame258.jpg
# [[  0.9837   0.0077   0.1798  58.3245]
#  [  0.0004   0.999   -0.0448  -0.4476]
#  [ -0.1799   0.0441   0.9827 100.4522]
#  [  0.       0.       0.       1.    ]]
# Mean Error Rotation: 0.00276
# Mean Error Translation: 0.59236
# == [Result] Frame: 259, Matches 258, Inliers: 78.68
# Saved at vis/frame259.jpg
# [[  0.9834   0.0068   0.1811  58.434 ]
#  [  0.0014   0.999   -0.0447  -0.4835]
#  [ -0.1812   0.0442   0.9824 101.0516]
#  [  0.       0.       0.       1.    ]]
# Mean Error Rotation: 0.00275
# Mean Error Translation: 0.59110
# == [Result] Frame: 260, Matches 259, Inliers: 80.31
# Saved at vis/frame260.jpg
# [[  0.9831   0.011    0.1829  58.5414]
#  [ -0.0035   0.9991  -0.0417  -0.519 ]
#  [ -0.1832   0.0403   0.9822 101.6577]
#  [  0.       0.       0.       1.    ]]
# Mean Error Rotation: 0.00275
# Mean Error Translation: 0.58983
# == [Result] Frame: 261, Matches 264, Inliers: 74.62
# Saved at vis/frame261.jpg
# [[  0.9827   0.0141   0.1846  58.6494]
#  [ -0.0075   0.9993  -0.0362  -0.5498]
#  [ -0.185    0.0342   0.9821 102.2822]
#  [  0.       0.       0.       1.    ]]
# Mean Error Rotation: 0.00275
# Mean Error Translation: 0.58851
# == [Result] Frame: 262, Matches 269, Inliers: 77.70
# Saved at vis/frame262.jpg
# [[  0.9819   0.0228   0.188   58.737 ]
#  [ -0.0171   0.9993  -0.032   -0.5899]
#  [ -0.1886   0.0282   0.9817 102.9402]
#  [  0.       0.       0.       1.    ]]
# Mean Error Rotation: 0.00277
# Mean Error Translation: 0.58711
# == [Result] Frame: 263, Matches 258, Inliers: 70.54
# Saved at vis/frame263.jpg
# [[  0.9814   0.0252   0.1905  58.8425]
#  [ -0.0183   0.9991  -0.0378  -0.6341]
#  [ -0.1913   0.0336   0.981  103.6028]
#  [  0.       0.       0.       1.    ]]
# Mean Error Rotation: 0.00278
# Mean Error Translation: 0.58559
# == [Result] Frame: 264, Matches 264, Inliers: 78.41
# Saved at vis/frame264.jpg
# [[  0.9814   0.0218   0.1909  58.9689]
#  [ -0.012    0.9986  -0.0521  -0.6745]
#  [ -0.1918   0.0488   0.9802 104.2734]
#  [  0.       0.       0.       1.    ]]
# Mean Error Rotation: 0.00277
# Mean Error Translation: 0.58400
# == [Result] Frame: 265, Matches 265, Inliers: 80.38
# Saved at vis/frame265.jpg
# [[  0.9815   0.0199   0.1902  59.1297]
#  [ -0.0083   0.9981  -0.0611  -0.7217]
#  [ -0.1911   0.0584   0.9798 105.0952]
#  [  0.       0.       0.       1.    ]]
# Mean Error Rotation: 0.00278
# Mean Error Translation: 0.58202
# == [Result] Frame: 266, Matches 271, Inliers: 74.91
# Saved at vis/frame266.jpg
# [[  0.9817   0.018    0.1897  59.3077]
#  [ -0.0082   0.9986  -0.0522  -0.7708]
#  [ -0.1904   0.0497   0.9804 106.0303]
#  [  0.       0.       0.       1.    ]]
# Mean Error Rotation: 0.00278
# Mean Error Translation: 0.58028
# == [Result] Frame: 267, Matches 279, Inliers: 77.42
# Saved at vis/frame267.jpg
# [[  0.9819   0.0123   0.1888  59.4236]
#  [ -0.0064   0.9995  -0.0317  -0.8046]
#  [ -0.1891   0.0299   0.9815 106.6409]
#  [  0.       0.       0.       1.    ]]
# Mean Error Rotation: 0.00279
# Mean Error Translation: 0.57905
# == [Result] Frame: 268, Matches 289, Inliers: 77.51
# Saved at vis/frame268.jpg
# [[  0.9822   0.0083   0.1874  59.5592]
#  [ -0.0053   0.9998  -0.0166  -0.8434]
#  [ -0.1876   0.0154   0.9821 107.3336]
#  [  0.       0.       0.       1.    ]]
# Mean Error Rotation: 0.00280
# Mean Error Translation: 0.57749
# == [Result] Frame: 269, Matches 275, Inliers: 76.73
# Saved at vis/frame269.jpg
# [[  0.9822   0.0141   0.1872  59.6785]
#  [ -0.0102   0.9997  -0.0221  -0.8793]
#  [ -0.1875   0.0198   0.9821 108.0339]
#  [  0.       0.       0.       1.    ]]
# Mean Error Rotation: 0.00281
# Mean Error Translation: 0.57586
# == [Result] Frame: 270, Matches 272, Inliers: 79.41
# Saved at vis/frame270.jpg
# [[  0.9821   0.0237   0.1869  59.7971]
#  [ -0.0168   0.9991  -0.0387  -0.9092]
#  [ -0.1877   0.0349   0.9816 108.8956]
#  [  0.       0.       0.       1.    ]]
# Mean Error Rotation: 0.00281
# Mean Error Translation: 0.57412
# == [Result] Frame: 271, Matches 269, Inliers: 76.95
# Saved at vis/frame271.jpg
# [[  0.9822   0.0251   0.186   59.9211]
#  [ -0.0168   0.9988  -0.046   -0.9451]
#  [ -0.1869   0.0421   0.9815 109.5773]
#  [  0.       0.       0.       1.    ]]
# Mean Error Rotation: 0.00281
# Mean Error Translation: 0.57253
# == [Result] Frame: 272, Matches 258, Inliers: 81.78
# Saved at vis/frame272.jpg
# [[  0.9825   0.0216   0.1848  60.0546]
#  [ -0.0132   0.9988  -0.0466  -0.9928]
#  [ -0.1856   0.0433   0.9817 110.3571]
#  [  0.       0.       0.       1.    ]]
# Mean Error Rotation: 0.00281
# Mean Error Translation: 0.57073
# == [Result] Frame: 273, Matches 261, Inliers: 82.38
# Saved at vis/frame273.jpg
# [[  0.9833   0.0202   0.1811  60.2057]
#  [ -0.0123   0.9989  -0.0446  -1.0505]
#  [ -0.1818   0.0416   0.9825 111.1252]
#  [  0.       0.       0.       1.    ]]
# Mean Error Rotation: 0.00281
# Mean Error Translation: 0.56888
# == [Result] Frame: 274, Matches 271, Inliers: 76.38
# Saved at vis/frame274.jpg
# [[  0.9839   0.0209   0.1776  60.3357]
#  [ -0.0129   0.9989  -0.046   -1.0922]
#  [ -0.1784   0.0429   0.983  111.9168]
#  [  0.       0.       0.       1.    ]]
# Mean Error Rotation: 0.00281
# Mean Error Translation: 0.56703
# == [Result] Frame: 275, Matches 270, Inliers: 79.26
# Saved at vis/frame275.jpg
# [[  0.9847   0.0211   0.1727  60.4927]
#  [ -0.013    0.9988  -0.0478  -1.1462]
#  [ -0.1735   0.0448   0.9838 112.8651]
#  [  0.       0.       0.       1.    ]]
# Mean Error Rotation: 0.00280
# Mean Error Translation: 0.56555
# == [Result] Frame: 276, Matches 269, Inliers: 74.35
# Saved at vis/frame276.jpg
# [[  0.985    0.0266   0.1706  60.6228]
#  [ -0.0186   0.9987  -0.0481  -1.2078]
#  [ -0.1717   0.0442   0.9842 113.8045]
#  [  0.       0.       0.       1.    ]]
# Mean Error Rotation: 0.00280
# Mean Error Translation: 0.56401
# == [Result] Frame: 277, Matches 258, Inliers: 61.24
# Saved at vis/frame277.jpg
# [[  0.9852   0.0313   0.1686  60.7427]
#  [ -0.0234   0.9985  -0.0485  -1.2503]
#  [ -0.1699   0.0439   0.9845 114.588 ]
#  [  0.       0.       0.       1.    ]]
# Mean Error Rotation: 0.00280
# Mean Error Translation: 0.56216
# == [Result] Frame: 278, Matches 269, Inliers: 66.91
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-5-9432022944e8> in <module>
#      93             plt.pause(0.1) # Or Option 2: enable to this to auto pause for a while after daring to enable animation in case of a delay in drawing
#      94         vis_path = os.path.join(save_path, 'frame%03d.jpg'%frame)
# ---> 95         fig.savefig(vis_path)
#      96         print('Saved at %s'%vis_path)
#      97
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2080                     orientation=orientation,
#    2081                     bbox_inches_restore=_bbox_inches_restore,
# -> 2082                     **kwargs)
#    2083             finally:
#    2084                 if bbox_inches and restore_bbox:
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_jpg(self, filename_or_obj, dryrun, pil_kwargs, *args, **kwargs)
#     577                 over *quality*, *optimize* and *progressive*.
#     578             """
# --> 579             buf, size = self.print_to_buffer()
#     580             if dryrun:
#     581                 return
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_to_buffer(self)
#     533
#     534     def print_to_buffer(self):
# --> 535         FigureCanvasAgg.draw(self)
#     536         renderer = self.get_renderer()
#     537         with cbook._setattr_cm(renderer, dpi=self.figure.dpi):
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1682                 ax.apply_aspect(pos)
#    1683             else:
# -> 1684                 ax.apply_aspect()
#    1685
#    1686             for child in ax.get_children():
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axes/_base.py in apply_aspect(self, position)
#    1511                 box_aspect = A * self.get_data_ratio()
#    1512             pb = position.frozen()
# -> 1513             pb1 = pb.shrunk_to_aspect(box_aspect, pb, fig_aspect)
#    1514             self._set_position(pb1.anchored(self.get_anchor(), pb), 'active')
#    1515             return
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/transforms.py in shrunk_to_aspect(self, box_aspect, container, fig_aspect)
#     601             H = h
#     602         return Bbox([self._points[0],
# --> 603                      self._points[0] + (W, H)])
#     604
#     605     def splitx(self, *args):
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/transforms.py in __init__(self, points, **kwargs)
#     738         """
#     739         BboxBase.__init__(self, **kwargs)
# --> 740         points = np.asarray(points, float)
#     741         if points.shape != (2, 2):
#     742             raise ValueError('Bbox points must be of the form '
#
# /opt/conda/lib/python3.7/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# KeyboardInterrupt:

# %% [markdown]
# 1. Report the final rotation and translation error. **(2 points)**

# %% [markdown]
# Mean Error Rotation: 0.00277 \
# Mean Error Translation: 0.53721

# %% [markdown]
# Then answer the questions below

# %% [markdown]
# 2. In $\mathtt{libviso2}$, the feature points are "bucketed" ($\mathtt{src/matcher.cpp: Line 285 - 326}$), which means in a certain area of region, the number of detected keypoint pairs should be within certain bounds. Why?  **(3 points)**

# %% [markdown]
# Several benifits are obtained by bucketing:
# 1. Reduce the total number of matched feature to reduce computational complexity
# 2. Ensure the features are evenly distrubuted along the vehicle z-axis which allows more precious estimation of linear and angluar velocities. It also allows the overall estimation process to use evenly disributed near/far features which result in a better overall estimation.
# 3. Ensure the image features are uniformly distributed over the whole image which make sure features are not overly distributed on independently moving objects. The even distribution also reduce drift rate.

# %% [markdown]
# 3. We have run SFM on a single camera, which means the scale of translation is unknown. However, as you may have observed, the predicted trajectory is still somewhat similar to the ground-truth trajectory. How does $\mathtt{libviso2}$ handle this ambiguity ($\mathtt{viso\_mono.cpp: Line 245}$)?  **(5 points)**

# %% [markdown]
# libviso2 handles this ambiguity by assuming a fixed transformation beteen the ground plane and the camera by using the height paramater and the estimated best pitch value to scale the translation.

# %% [markdown]
# 4. Briefly explain the RANSAC algorithm used in $\mathtt{libviso2}$ ($\mathtt{viso\_mono.cpp: Line 113 - 129}$).  **(5 points)**

# %% [markdown]
# For specfied number of iteration:
# 1. Randomly draw 8 points from the matching points
# 2. Use this 8 points drew in the 8 point algotrithm to estimatie the fundamental matrix F
# 3. Use the estimated fundamental matrix F to calculate the number of inliners in the matching points
# 4. If the number of inliner is larger than the current largest inliner size, update the saved inliners to the new inliners

# %% [markdown]
# ## Question 2: Using SIFT [4] for SFM

# %% [markdown]
# In the second task, you are required to use keypoints and feature descriptors from SIFT for SFM. The SIFT implementation can be found in directory $\mathtt{SIFT}$.
#
# (A) Go to $\mathtt{SIFT}$ directory and run $\mathtt{runSIFT.py}$ (e.g. `python runSIFT.py --input /datasets/cs252-sp21-A00-public/dataset_SfM/sequences/00/image_0/`). You will save the detected keypoints and feature descriptors under the directory $\mathtt{SIFT}$. For image $\mathtt{000abc.png}$, the pre-computed features and keypoints should be saved in a $\mathtt{.npy}$ file named as $\mathtt{000abc\_feature.npy}$. The variable should be a $130 \times N$ matrix with $\mathtt{single}$ precision, where $N$ is the number of feature points being detected. For each $130$-dimensional feature vector, the first two dimensions are the location of the keypoints (column number first and then row number) on the image plane and the last $128$ dimensions are the feature descriptor.
#
# (B) Run the following script

# %%
import runFeature
dataset_path = '/datasets/cs252-sp21-A00-public/dataset_SfM'
feature_dir = 'SIFT'
runFeature.runSFM(dataset_path, feature_dir )

# %% [markdown]
# 1. Report the final rotation and translation error. **(2 points)**

# %% [markdown]
# Mean Error Rotation: 0.00243 \
# Mean Error Translation: 0.55841

# %% [markdown]
# Next, answer the following questions:

# %% [markdown]
# 2. Does SIFT yield higher accuracy than the original $\mathtt{libviso2}$? Why or why not? If not, can you suggest one possible way to improve? **(5 points)**

# %% [markdown]
# SIFT yields higher accracy in Rotation but lower accracy in translation. The reason for high rotation accuracy is becase SIFT is a accurate detctor that achieves rotation invarince. The reason for lower rotation accuracy is maybe that the SIFT implemenation didn't use bucketing, which can be told from Frame 200 of the two implematations where origial implmentation has a even distributed features while SIFT implmentation has a skewed distrubution. Therefore, the SIFT implementation will not have the benefit of bucketing and affect the translation acuracy negatively. One way to improve is to also use bucketing on SIFT features before input them into the next stage of the pipeline.

# %% [markdown]
# 3. Explain how SIFT achieves invariance to
#        a. illumination
#        b. rotation
#        c. scale
#  **(3 points)**

# %% [markdown]
# a. illumination: the SIFT descriptor then use image gradient to form 8 bin histogram to fuse 128 featrue directions for each keypoint which is robust againt gradute illumination changes \
# b. rotation: Each keypoint is assigned with an orienttion of the max local gradient direction, then keypoint is rotated base on the histogram in the normalization step \
# c. scale: Use Scale Space Pyramid to find the maxima of difference-of Gaussian in scale space which are reliable under different scale, normalize the keypoint using this scale

# %% [markdown]
# ## Question 3: Using SuperPoint[1] for SFM

# %% [markdown]
# Now you are required to use keypoints and feature descriptors from SuperPoint for SFM. The code for the trained model of this method can be found from the $\mathtt{SuperPoint}$.
#
# (A) Go to $\mathtt{SuperPoint}$ directory and run $\mathtt{demo\_superpoint.py}$ (e.g. `python demo_superpoint.py --input /datasets/cs252-sp21-A00-public/dataset_SfM/sequences/00/image_0/`). The detected keypoints and feature descriptors are under the directory $\mathtt{SuperPoint}$. The file format is similar to the SIFT case. For image $\mathtt{000abc.png}$, the pre-computed features and keypoints should be saved in a $\mathtt{.npy}$ file named as $\mathtt{000abc\_feature.npy}$. The variable is a $258\times N$ matrix with $\mathtt{single}$ precision, where $N$ is the number of feature points being detected. For each $258$-dimensional feature vector, the first two dimensions are the locations of the keypoint (column number first and then row number) on the image plane and the last $256$ dimensions represent the feature descriptor.
#
# (B) Run the following script

# %%
import runFeature
dataset_path = '/datasets/cs252-sp21-A00-public/dataset_SfM'
feature_dir = 'SuperPoint'
runFeature.runSFM(dataset_path, feature_dir )

# %% [markdown]
# 1. Report the final rotation and translation error. **(2 points)**

# %% [markdown]
# Mean Error Rotation: 0.00369 \
# Mean Error Translation: 0.52405

# %% [markdown]
# Next, answer the following questions:

# %% [markdown]
# 2. Does SuperPoint yield higher accuracy than the original $\mathtt{libviso2}$? If so, why? If not, what steps can you take to improve? **(5 points)**

# %% [markdown]
# SuperPoint yields higher accracy in Translattion but lower accracy in Rotation. The reason for higher translation accuracy is becase SuperPoint can generate a evently distrubuted, highly accurate keypoints, better than the original bucketing approach. The reason for lower rotation accracy is the keypoint generated by SuperPoint is less robust when rotating. Maybe train the SuperPoint with more rotating homographies.

# %% [markdown]
# 3. Explain briefly how the following issues are being handled in SuperPoint: **(3 points)**
#        a. Obtaining ground truth for keypoints.
#        b. Cheaply obtaining accurate ground truth matches, as compared to LIDAR in UCN or SFM in LIFT.
#        c. Learning a correlated feature representation for keypoint detection and description?

# %% [markdown]
# a. Train a base dector with synthetic data, then use the base dector to detect an image seen from randomly generated different points of view, then combined these detected points from different views to form a keypoint ground truth. (Homographic Adaptation) \
# b. Since homographies are used to generated different view points of the same image, the almost exact image-to-image matches are captured in the homography transformation \
# c. The overall lose function combines the detector loss and descriptor loss, the training input has both ground truth keep point location and ground truth correspondence location

# %% [markdown]
# ## Question 4: Using SPyNet [5] for SFM

# %% [markdown]
# Now we will compute camera motion from optical flow computed using SPyNet. We first uniformly sample points in an image, then consider the flow-displaced point in the other image as a match. A modified PyTorch implementation of SPyNet is provided in directory  $\mathtt{Flow}$.
#
# (A) Go to $\mathtt{Flow}$ and run $\mathtt{demo\_spynet.py}$. (e.g. `python demo_spynet.py --input /datasets/cs252-sp21-A00-public/dataset_SfM/sequences/00/image_0/`).
#
# (B) Run the following script.

# %%
import runMatch
dataset_path = '/datasets/cs252-sp21-A00-public/dataset_SfM'
feature_dir = 'Flow'
runMatch.runSFM(dataset_path, feature_dir )

# %% [markdown]
# 1. Report the final rotation and translation error. **(2 points)**

# %% [markdown]
# Mean Error Rotation: 0.00380 \
# Mean Error Translation: 0.61071

# %% [markdown]
# Next, answer the following questions:

# %% [markdown]
# 2. Does SPyNet yield higher accuracy than the original $\mathtt{libviso2}$? Why or why not? If not, what steps can you take to improve? **(5 points)**

# %% [markdown]
# It yields lower accuracy than libviso2. It could be due to that the features detected by the optical flow is not as good as feature detacted by the above feature dectors, although the CNN used can improve the optical flow quality, it still has some limitations as the traditional optical flow methods such as "large motions of small or thin objects" as the author points out. To improve, maybe also introduces some triditional methods that accounts for this type of limitations in the implementation.

# %% [markdown]
# 3. Explain how SPyNet achieves accurate flow with significantly lower computational cost. **(3 points)**

# %% [markdown]
# It kept the traditional coarse-to-ﬁne spatial pyramid structure, but use CNN at each level to calculate the flow increment at each level. Therefore, it doesn't need to rely on assumption like traditional methods did due to the use of CNN which improves performance, and it doesn't need to have a very large CNN architecture since CNN is not doing all the works.

# %% [markdown]
# ## Question 5: Using Sfm-learner for SFM
# Now we will use deep neural networks for SFM. Please follow the open-source Sfmlearner repository (https://github.com/ClementPinard/SfmLearner-Pytorch) and the paper (https://people.eecs.berkeley.edu/~tinghuiz/projects/SfMLearner/cvpr17_sfm_final.pdf) to answer the following questions.

# %% [markdown]
# 1. Describe how photometric loss is implemented in Sfmlearner? Please refer to the paper and the code. **(5 points)**

# %% [markdown]
# The photometric loss is implemented as the sum of difference over all pixel coordinates over all source images. The difference is defined as the difference between the pixel value of target frame and the pixel value of source frame projected to the target coordinate frame using the predicted depth and pose transformation of the model.

# %% [markdown]
# 2. Train the model and show the training curve, validation curve, and visualization of predicted depth and warped images? Which loss is decreasing and which is increasing? Why? **(10 points)**
#
#  Visualize the specific images: `val_Depth_Output_Normalized/0`, `val_Warped_Outputs/0` from tensorboard.
#
#  Training data:
# `/datasets/cs252-sp21-A00-public/sfmlearner_h128w416`.
#
# #### Install the environment
# `pip install -r requirements.txt --user`
# - fix scipy version problem:
#
# `pip install scipy==1.1.0 --user`
#
# #### Training script
# `cd SfmLearner-Pytorch`
#
# `python3 train.py /datasets/cs252-sp21-A00-public/sfmlearner_h128w416 -b4 -m0.2 -s0.1 --epoch-size 3000 --sequence-length 3 --log-output`

# %% [markdown]
# Total Loss Curve:
# ![total_loss_default.png](attachment:total_loss_default.png)
#
# Validation Curve:
# ![val_loss_default.png](attachment:val_loss_default.png)
#
# Predicted Depth:
# ![depth_default.png](attachment:depth_default.png)
#
# Warped Images:
# ![warped_default.png](attachment:warped_default.png)

# %% [markdown]
# All the loss except disparity_smoothness_loss decreases. disparity_smoothness_loss increases since as the depth prediction gets better, the smoothness would decrease as the real world data. All other loss decreases as they are defined to decrease as the model gets better.

# %% [markdown]
# 3. When training the model, we use 3 consecutive frames. Now, you will use the photometric consistency between the 1st and the 3rd frame. To be more specific, you can get the pose $T_{1,3} = T_{2,3} @ T_{1,2}$, where $T_{1,2}, T_{2,3}$ have already been computed in the original code. Add the constraint to the total loss and report the results in the same manner as in part 2 above. You can simply ignore the explainability mask between 1st and 3rd frame. **(10 points)**

# %% [markdown]
# Trained for less epoch due to training time increase
# Total Loss:
# ![total_loss_diy.png](attachment:total_loss_diy.png)
#
# Val Loss:
# ![val_loss_diy.png](attachment:val_loss_diy.png)
#
# Depth:
# ![depth_diy.png](attachment:depth_diy.png)
#
# Image:
# ![warped_diy.png](attachment:warped_diy.png)

# %% [markdown]
# 4. Now, you will evaluate your models from parts (2), (3) on the KITTI odometry dataset. What are the error metrics used in Sfm-learner? Please report the `ATE` and `RE` for sequence `09` and `10`. **(5 points)**
#
#   Data: `/datasets/cs252-sp21-A00-public/kitti`.
#
# #### Evaluation script
# `python3 test_pose.py /path/to/posenet --dataset-dir /datasets/cs252-sp21-A00-public/kitti --sequences 09`

# %% [markdown]
# Sequence 9: \
# Due to datahub complication and version changes, models have to be retrained serveral time and the part 2 result is with 6k training image and part 3 result is with 1.5k training image.
#
# Part 2 Results  ATE,         RE \
# mean         0.0306,     0.0040 \
# std          0.0301,     0.0029
#
# Part 3 Results  ATE,         RE \
# mean            0.0298,      0.0124 \
# std             0.0109,      0.0112
#
# Sequence 10: \
# Part 2 Results  ATE,         RE \
# mean         0.0244,     0.0042 \
# std          0.0248,     0.0032
#
# Part 3 Results  ATE,        RE  \
# mean         0.0221,     0.0102 \
# std          0.0126,     0.0126

# %% [markdown]
# ### Notes:
# - scp data to local machines:
#
# `scp <USERNAME>@dsmlp-login.ucsd.edu:/datasets/cs252-sp21-A00-public/sfmlearner_h128w416.zip <LOCAL PATH>`
#
# `scp <USERNAME>@dsmlp-login.ucsd.edu:/datasets/cs252-sp21-A00-public/kitti.zip <LOCAL PATH>`
# ...
# - tensorboard: open jupyter notebook from the link after launching the container. Go to checkpoint directory and click new -> `Tensorboard`

# %% [markdown]
# # References
# 1. Daniel DeTone, Tomasz Malisiewicz, and Andrew Rabinovich. Superpoint: Self-supervised interest point detection and description. In Proceedings of the IEEE Conference on Computer Vision and Pattern Recognition Workshops, pages 224–236, 2018.
# 2. Andreas Geiger, Philip Lenz, and Raquel Urtasun. Are we ready for autonomous driving? the kitti vision benchmark suite. In Conference on Computer Vision and Pattern Recognition (CVPR), 2012.
# 3. Andreas Geiger, Julius Ziegler, and Christoph Stiller. Stereoscan: Dense 3d reconstruction in real-time. In Intelligent Vehicles Symposium (IV), 2011.
# 4. David G Lowe. Distinctive image features from scale-invariant keypoints. IJCV, 60(2):91–110, 2004.
# 5. Anurag Ranjan and Michael J Black. Optical flow estimation using a spatial pyramid network. In
# Proceedings of the IEEE Conference on Computer Vision and Pattern Recognition, pages 4161–4170, 2017.
# 6. A. Vedaldi and B. Fulkerson. VLFeat: An open and portable library of computer vision algorithms. http://www.vlfeat.org/, 2008.
# 7. Lucas, Bruce D., and Takeo Kanade. "An iterative image registration technique with an application to stereo vision." (1981): 674.
# 8. B. Kitt, A. Geiger, and H. Lategahn, “Visual odometry based on stereo image sequences with RANSAC-based outlier rejection scheme,” in 2010 IEEE Intelligent Vehicles Symposium, La Jolla, CA, USA, Jun. 2010, pp. 486–492, doi: 10.1109/IVS.2010.5548123.
# 9. A. Geiger, J. Ziegler, and C. Stiller, “StereoScan: Dense 3d reconstruction in real-time,” in 2011 IEEE Intelligent Vehicles Symposium (IV), Baden-Baden, Germany, Jun. 2011, pp. 963–968, doi: 10.1109/IVS.2011.5940405.
